# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB_diversity.csv")
df = df[['Sample','shannon_index_TCR','repertoire_type','tissue_type','class']]
df.drop_duplicates(keep='first', inplace=True)
df
# Out:
#           Sample  shannon_index_TCR repertoire_type  tissue_type  \
# 0     SRR5233637           7.712411      polyclonal  T_cell_poor
# 3     SRR5233639          10.059157      polyclonal  T_cell_rich
# 6       sample01           1.072675      monoclonal  T_cell_rich
# 9       sample02           1.001202      monoclonal  T_cell_rich
# 12      sample03           0.960516      monoclonal  T_cell_rich
# 15      sample04           9.598323      polyclonal  T_cell_rich
# 18      sample05           8.005115      polyclonal  T_cell_rich
# 21      sample06           8.172351      polyclonal  T_cell_poor
# 24      sample08           8.035551      polyclonal  T_cell_poor
# 27      sample09           7.651713      polyclonal  T_cell_poor
# 30      sample10           7.207395      polyclonal  T_cell_poor
# 33      sample11           7.730309      polyclonal  T_cell_poor
# 36      sample12           6.546400      polyclonal  T_cell_poor
# 39      sample13           1.520791      monoclonal  T_cell_poor
# 42      sample14           6.941821      polyclonal  T_cell_poor
# 45  TCGA-CZ-4862           7.485462      polyclonal  T_cell_poor
# 47  TCGA-CZ-5463           2.957966      polyclonal  T_cell_poor
# 49  TCGA-CZ-5985           5.638249      polyclonal  T_cell_poor
# 51      sample07           4.680209      polyclonal  T_cell_poor
#
#                      class
# 0   T_cell_poor_polyclonal
# 3   T_cell_rich_polyclonal
# 6   T_cell_rich_monoclonal
# 9   T_cell_rich_monoclonal
# 12  T_cell_rich_monoclonal
# 15  T_cell_rich_polyclonal
# 18  T_cell_rich_polyclonal
# 21  T_cell_poor_polyclonal
# 24  T_cell_poor_polyclonal
# 27  T_cell_poor_polyclonal
# 30  T_cell_poor_polyclonal
# 33  T_cell_poor_polyclonal
# 36  T_cell_poor_polyclonal
# 39  T_cell_poor_monoclonal
# 42  T_cell_poor_polyclonal
# 45  T_cell_poor_polyclonal
# 47  T_cell_poor_polyclonal
# 49  T_cell_poor_polyclonal
# 51  T_cell_poor_polyclonal

# %%
f, ax = plt.subplots(figsize=(10,10))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.stripplot(x='Sample', y='shannon_index_TCR', hue='repertoire_type', data=df, s=10,
                    order=['sample01','sample02','sample03','sample04','sample05','sample06','sample07','sample08',
                          'sample09','sample10','sample11','sample12','sample13','sample14','SRR5233637','SRR5233639',
                          'TCGA-CZ-4862','TCGA-CZ-5463','TCGA-CZ-5985'], hue_order = ['monoclonal','polyclonal'], palette="muted")
ax.axhline(y=2, color='#8c613c',ls='--')

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(loc='upper right', bbox_to_anchor=(0.3, 1.05), frameon=False)

g.set_xlabel("Sample",fontsize=20)
g.set_ylabel("TCR-Seq-based Shannon Diversity Index (SDI)",fontsize=20)
plt.xticks(rotation=90)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.setp(ax.get_legend().get_texts(), fontsize=20) 
plt.setp(ax.get_legend().get_title(), fontsize=20)
sns.despine()

plt.savefig("../figures/supplementary/figureS1.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS1.png",bbox_inches="tight")
plt.show()
