# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../summary_data/subsample/subsample_diversity.csv")
df
# Out:
#       Sample  shannon_index_TCR  shannon_index_tool    tool  \
# 0   sample01           1.072675            0.448437   MIXCR
# 1   sample01           1.072675            0.547504   IMREP
# 2   sample01           1.072675            0.518910  TRUST4
# 3   sample01           1.072675            0.389090   MIXCR
# 4   sample01           1.072675            0.459795   IMREP
# 5   sample01           1.072675            0.461263  TRUST4
# 6   sample01           1.072675            0.372418   MIXCR
# 7   sample01           1.072675            0.406998   IMREP
# 8   sample01           1.072675            0.396686  TRUST4
# 9   sample01           1.072675            0.366791   MIXCR
# 10  sample01           1.072675            0.386767   IMREP
# 11  sample01           1.072675            0.376255  TRUST4
# 12  sample01           1.072675            0.367031   MIXCR
# 13  sample01           1.072675            0.365682   IMREP
# 14  sample01           1.072675            0.365682  TRUST4
# 15  sample02           1.001202            0.526335   MIXCR
# 16  sample02           1.001202            1.009263   IMREP
# 17  sample02           1.001202            0.717945  TRUST4
# 18  sample02           1.001202            0.412935   MIXCR
# 19  sample02           1.001202            0.607380   IMREP
# 20  sample02           1.001202            0.557980  TRUST4
# 21  sample02           1.001202            0.370954   MIXCR
# 22  sample02           1.001202            0.412965   IMREP
# 23  sample02           1.001202            0.444505  TRUST4
# 24  sample02           1.001202            0.367854   MIXCR
# 25  sample02           1.001202            0.391210   IMREP
# 26  sample02           1.001202            0.421393  TRUST4
# 27  sample02           1.001202            0.367879   MIXCR
# 28  sample02           1.001202            0.363360   IMREP
# 29  sample02           1.001202            0.364596  TRUST4
# 30  sample03           0.960516            0.564798   MIXCR
# 31  sample03           0.960516            0.701097   IMREP
# 32  sample03           0.960516            0.637789  TRUST4
# 33  sample03           0.960516            0.490193   MIXCR
# 34  sample03           0.960516            0.544536   IMREP
# 35  sample03           0.960516            0.540777  TRUST4
# 36  sample03           0.960516            0.457819   MIXCR
# 37  sample03           0.960516            0.450677   IMREP
# 38  sample03           0.960516            0.455030  TRUST4
# 39  sample03           0.960516            0.457339   MIXCR
# 40  sample03           0.960516            0.425738   IMREP
# 41  sample03           0.960516            0.431062  TRUST4
# 42  sample03           0.960516            0.452226   MIXCR
# 43  sample03           0.960516            0.384446   IMREP
# 44  sample03           0.960516            0.386190  TRUST4
#
#     new_total_reads_tool  est_reads  clonotype_count_tool  absolute_error
# 0                  28349      28000                   219        0.624237
# 1                  28349      28000                   369        0.525171
# 2                  28349      28000                   316        0.553765
# 3                  13889      13500                    31        0.683585
# 4                  13889      13500                    93        0.612880
# 5                  13889      13500                   109        0.611412
# 6                   2739       2600                     3        0.700256
# 7                   2739       2600                    13        0.665677
# 8                   2739       2600                    11        0.675989
# 9                   1362       1300                     1        0.705884
# 10                  1362       1300                     5        0.685907
# 11                  1362       1300                     3        0.696420
# 12                   271        260                     1        0.705644
# 13                   271        260                     1        0.706992
# 14                   271        260                     1        0.706992
# 15                 27968      28000                   412        0.474866
# 16                 27968      28000                  1597        0.008061
# 17                 27968      28000                   739        0.283256
# 18                 13024      13500                    57        0.588266
# 19                 13024      13500                   288        0.393822
# 20                 13024      13500                   181        0.443221
# 21                  2506       2600                     2        0.630247
# 22                  2506       2600                    14        0.588236
# 23                  2506       2600                    26        0.556696
# 24                  1246       1300                     1        0.633348
# 25                  1246       1300                     6        0.609992
# 26                  1246       1300                    11        0.579808
# 27                   247        260                     1        0.633323
# 28                   247        260                     1        0.637842
# 29                   247        260                     1        0.636605
# 30                 28308      28000                   285        0.395718
# 31                 28308      28000                   670        0.259420
# 32                 28308      28000                   472        0.322727
# 33                 13684      13500                    50        0.470323
# 34                 13684      13500                   158        0.415980
# 35                 13684      13500                   138        0.419739
# 36                  2674       2600                     5        0.502697
# 37                  2674       2600                    21        0.509840
# 38                  2674       2600                    19        0.505486
# 39                  1328       1300                     4        0.503178
# 40                  1328       1300                     9        0.534779
# 41                  1328       1300                    11        0.529455
# 42                   261        260                     3        0.508290
# 43                   261        260                     2        0.576071
# 44                   261        260                     2        0.574326

# %%
sns.set_style('white')
sns.set_context('talk')

fig, ax = plt.subplots(figsize=(10, 10))
ax = sns.barplot(data=df, x="tool", y="absolute_error", hue="est_reads",palette="muted")

ax.set(ylim=(0,1))
ax.set_xlabel('Tools')
ax.set_ylabel('Absolute error of SDI')
sns.despine()

plt.savefig("../figures/supplementary/figureS4_b.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS4_b.png",bbox_inches="tight")

# %%
mean_diversity_combined = df.groupby(["tool","est_reads"])["absolute_error"].mean().reset_index()
mean_diversity_combined = mean_diversity_combined.sort_values('est_reads')
mean_diversity_combined
# Out:
#       tool  est_reads  absolute_error
# 0    IMREP        260        0.640302
# 5    MIXCR        260        0.615752
# 10  TRUST4        260        0.639308
# 1    IMREP       1300        0.610226
# 6    MIXCR       1300        0.614136
# 11  TRUST4       1300        0.601894
# 2    IMREP       2600        0.587918
# 7    MIXCR       2600        0.611067
# 12  TRUST4       2600        0.579390
# 3    IMREP      13500        0.474227
# 8    MIXCR      13500        0.580725
# 13  TRUST4      13500        0.491457
# 4    IMREP      28000        0.264217
# 9    MIXCR      28000        0.498274
# 14  TRUST4      28000        0.386583
