# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
est_reads = ['28000','13500','2600','1300','260']

# %% [markdown]
# ## MIXCR

# %%
df_MIXCR = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_MIXCR_'+reads+'.csv')
    df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
    df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)
    
    df_MIXCR = pd.merge(df_MIXCR, df_temp_aa, how='right', on=['th'])

df_MIXCR
# Out:
#               th  observed_portion_frequency_28000  \
# 0       0.000000                          0.922054
# 1       0.001000                          0.937342
# 2       0.002000                          0.940275
# 3       0.003000                          0.974777
# 4       0.004000                          0.985473
# ...          ...                               ...
# 91726  91.726917                          1.000000
# 91727  91.727917                          1.000000
# 91728  91.728917                          1.000000
# 91729  91.729917                          1.000000
# 91730  91.730917                          1.000000
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.917583                         0.913357
# 1                              0.932869                         0.928544
# 2                              0.935992                         0.931669
# ...

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 4))

sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_260'],label='260',color='#4878d0')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['260','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by MIXCR')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.3,fontsize=16)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(16)
ax.yaxis.label.set_size(16)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)
    
plt.savefig("../figures/supplementary/figureS4_a1.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS4_a1.png",bbox_inches="tight")
plt.show(block=False)
# Out:
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## IMREP

# %%
df_IMREP = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_IMREP_'+reads+'.csv')
    df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
    df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)

    df_IMREP = pd.merge(df_IMREP, df_temp_aa, how='right', on=['th'])

df_IMREP
# Out:
#               th  observed_portion_frequency_28000  \
# 0       0.000000                          0.922284
# 1       0.001000                          0.937472
# 2       0.002000                          0.940377
# 3       0.003000                          0.974403
# 4       0.004000                          0.984920
# ...          ...                               ...
# 91726  91.726917                          1.000000
# 91727  91.727917                          1.000000
# 91728  91.728917                          1.000000
# 91729  91.729917                          1.000000
# 91730  91.730917                          1.000000
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.917800                         0.913454
# 1                              0.933052                         0.928644
# 2                              0.936156                         0.931771
# ...

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 4))

sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_260'],label='260',color='#4878d0')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['260','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by IMREP')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.3,fontsize=16)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(16)
ax.yaxis.label.set_size(16)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)
    
plt.savefig("../figures/supplementary/figureS4_a2.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS4_a2.png",bbox_inches="tight")
plt.show(block=False)
# Out:
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## TRUST4

# %%
df_TRUST4 = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_TRUST4_'+reads+'.csv')
    df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
    df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)

    df_TRUST4 = pd.merge(df_TRUST4, df_temp_aa, how='right', on=['th'])

df_TRUST4
# Out:
#               th  observed_portion_frequency_28000  \
# 0       0.000000                          0.922345
# 1       0.001000                          0.937587
# 2       0.002000                          0.940536
# 3       0.003000                          0.974858
# 4       0.004000                          0.985553
# ...          ...                               ...
# 91726  91.726917                          1.000000
# 91727  91.727917                          1.000000
# 91728  91.728917                          1.000000
# 91729  91.729917                          1.000000
# 91730  91.730917                          1.000000
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.918522                         0.913908
# 1                              0.933784                         0.929108
# 2                              0.936888                         0.932232
# ...

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 4))

sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_260'],label='260',color='#4878d0')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['260','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by TRUST4')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.3,fontsize=16)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(16)
ax.yaxis.label.set_size(16)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)
    
plt.savefig("../figures/supplementary/figureS4_a3.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS4_a3.png",bbox_inches="tight")
plt.show(block=False)
# Out:
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/keruipeng/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
