# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB.csv")
df
# Out:
#             Sample               CDR3  nReads_TCR  nReads_CATT  nReads_MIXCR  \
# 0       SRR5233637   CASSPRVTSGTYEQYF        32.0          0.0           0.0
# 1       SRR5233637    CASSYSDRGGQPQHF        13.0          0.0           0.0
# 2       SRR5233637     CASKVALGGETQYF        25.0          0.0           0.0
# 3       SRR5233637  CASRAPGTGTLGSPLHF        66.0          0.0           0.0
# 4       SRR5233637   CASSSGQGGPSTEAFF        52.0          0.0           0.0
# ...            ...                ...         ...          ...           ...
# 378937    sample14    CASSESPAFGEKLFF         0.0          0.0           0.0
# 378938    sample14     CASSWTGSQETQYF         0.0          0.0           0.0
# 378939    sample14   CASRTGLAGGIGELFF         0.0          0.0           0.0
# 378940    sample14       CASSVEGYEQYF         0.0          0.0           0.0
# 378941    sample14    CASSQQGDSNQPQHF         0.0          0.0           0.0
#
# ...

# %%
# Select T cell rich low SDI samples
low_SDI = df.loc[df['Sample'].isin(['sample01','sample02','sample03'])]

# %% [markdown]
# ## MIXCR

# %%
MIXCR = low_SDI[['Sample','class','tissue','tissue_type','repertoire_type','CDR3','nReads_TCR','nReads_MIXCR']]
MIXCR = MIXCR.loc[(MIXCR['nReads_TCR'] != 0) & (MIXCR['nReads_MIXCR'] != 0)]

# %%
# Calculate total number of reads in each sample
total_reads_MIXCR = MIXCR[['Sample','nReads_TCR','nReads_MIXCR']].groupby('Sample').sum().rename(columns={'nReads_TCR':'total_reads_TCR','nReads_MIXCR':'total_reads_MIXCR'})

# Merge dataframes 
MIXCR = pd.merge(MIXCR, total_reads_MIXCR, how='outer', on=['Sample']).fillna(0)

# Renormalize the frequency
MIXCR['renormalized_frequency_TCR'] = MIXCR['nReads_TCR'] / (MIXCR['total_reads_TCR'] * 1.0)
MIXCR['renormalized_frequency_MIXCR'] = MIXCR['nReads_MIXCR'] / (MIXCR['total_reads_MIXCR'] * 1.0)
MIXCR.fillna(0, inplace=True)

# %%
MIXCR_sample01 = MIXCR.loc[MIXCR['Sample'] == 'sample01']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_MIXCR', hue='class', s=20, data=MIXCR_sample01, palette=['#4878d0'])
g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(MIXCR_sample01['renormalized_frequency_TCR'], MIXCR_sample01['renormalized_frequency_MIXCR'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)

g.axes.set_title('MIXCR - sample01',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8a.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8a.png",bbox_inches="tight")

plt.show()

# %%
MIXCR_sample02 = MIXCR.loc[MIXCR['Sample'] == 'sample02']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_MIXCR', hue='class', s=20, data=MIXCR_sample02, palette=['#4878d0'])
g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(MIXCR_sample02['renormalized_frequency_TCR'], MIXCR_sample02['renormalized_frequency_MIXCR'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)

g.axes.set_title('MIXCR - sample02',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8e.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8e.png",bbox_inches="tight")

plt.show()

# %%
MIXCR_sample03 = MIXCR.loc[MIXCR['Sample'] == 'sample03']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_MIXCR', hue='class', s=20, data=MIXCR_sample03, palette=['#4878d0'])
g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(MIXCR_sample03['renormalized_frequency_TCR'], MIXCR_sample03['renormalized_frequency_MIXCR'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)

g.axes.set_title('MIXCR - sample03',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8i.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8i.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## IMREP

# %%
IMREP = low_SDI[['Sample','class','tissue','tissue_type','repertoire_type','CDR3','nReads_TCR','nReads_IMREP']]
IMREP = IMREP.loc[(IMREP['nReads_TCR'] != 0) & (IMREP['nReads_IMREP'] != 0)]

# %%
# Calculate total number of reads in each sample
total_reads_IMREP = IMREP[['Sample','nReads_TCR','nReads_IMREP']].groupby('Sample').sum().rename(columns={'nReads_TCR':'total_reads_TCR','nReads_IMREP':'total_reads_IMREP'})

# Merge dataframes 
IMREP = pd.merge(IMREP, total_reads_IMREP, how='outer', on=['Sample']).fillna(0)

# Renormalize the frequency
IMREP['renormalized_frequency_TCR'] = IMREP['nReads_TCR'] / (IMREP['total_reads_TCR'] * 1.0)
IMREP['renormalized_frequency_IMREP'] = IMREP['nReads_IMREP'] / (IMREP['total_reads_IMREP'] * 1.0)
IMREP.fillna(0, inplace=True)

# %%
IMREP_sample01 = IMREP.loc[IMREP['Sample'] == 'sample01']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_IMREP', hue='class', s=20, data=IMREP_sample01, palette=['#ee854a'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(IMREP_sample01['renormalized_frequency_TCR'], IMREP_sample01['renormalized_frequency_IMREP'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('IMREP - sample01',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8b.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8b.png",bbox_inches="tight")

plt.show()

# %%
IMREP_sample02 = IMREP.loc[IMREP['Sample'] == 'sample02']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_IMREP', hue='class', s=20, data=IMREP_sample02, palette=['#ee854a'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(IMREP_sample02['renormalized_frequency_TCR'], IMREP_sample02['renormalized_frequency_IMREP'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('IMREP - sample02',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8f.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8f.png",bbox_inches="tight")

plt.show()

# %%
IMREP_sample03 = IMREP.loc[IMREP['Sample'] == 'sample03']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_IMREP', hue='class', s=20, data=IMREP_sample03, palette=['#ee854a'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(IMREP_sample03['renormalized_frequency_TCR'], IMREP_sample03['renormalized_frequency_IMREP'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('IMREP - sample03',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8j.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8j.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TRUST4

# %%
TRUST4 = low_SDI[['Sample','class','tissue','tissue_type','repertoire_type','CDR3','nReads_TCR','nReads_TRUST4']]
TRUST4 = TRUST4.loc[(TRUST4['nReads_TCR'] != 0) & (TRUST4['nReads_TRUST4'] != 0)]

# %%
# Calculate total number of reads in each sample
total_reads_TRUST4 = TRUST4[['Sample','nReads_TCR','nReads_TRUST4']].groupby('Sample').sum().rename(columns={'nReads_TCR':'total_reads_TCR','nReads_TRUST4':'total_reads_TRUST4'})

# Merge dataframes 
TRUST4 = pd.merge(TRUST4, total_reads_TRUST4, how='outer', on=['Sample']).fillna(0)

# Renormalize the frequency
TRUST4['renormalized_frequency_TCR'] = TRUST4['nReads_TCR'] / (TRUST4['total_reads_TCR'] * 1.0)
TRUST4['renormalized_frequency_TRUST4'] = TRUST4['nReads_TRUST4'] / (TRUST4['total_reads_TRUST4'] * 1.0)
TRUST4.fillna(0, inplace=True)

# %%
TRUST4_sample01 = TRUST4.loc[TRUST4['Sample'] == 'sample01']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_TRUST4', hue='class', s=20, data=TRUST4_sample01, palette=['#6acc64'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(TRUST4_sample01['renormalized_frequency_TCR'], TRUST4_sample01['renormalized_frequency_TRUST4'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('TRUST4 - sample01',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8c.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8c.png",bbox_inches="tight")

plt.show()

# %%
TRUST4_sample02 = TRUST4.loc[TRUST4['Sample'] == 'sample02']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_TRUST4', hue='class', s=20, data=TRUST4_sample02, palette=['#6acc64'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(TRUST4_sample02['renormalized_frequency_TCR'], TRUST4_sample02['renormalized_frequency_TRUST4'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('TRUST4 - sample02',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8g.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8g.png",bbox_inches="tight")

plt.show()

# %%
TRUST4_sample03 = TRUST4.loc[TRUST4['Sample'] == 'sample03']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_TRUST4', hue='class', s=20, data=TRUST4_sample03, palette=['#6acc64'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(TRUST4_sample03['renormalized_frequency_TCR'], TRUST4_sample03['renormalized_frequency_TRUST4'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('TRUST4 - sample03',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8k.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8k.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## CATT

# %%
CATT = low_SDI[['Sample','class','tissue','tissue_type','repertoire_type','CDR3','nReads_TCR','nReads_CATT']]
CATT = CATT.loc[(CATT['nReads_TCR'] != 0) & (CATT['nReads_CATT'] != 0)]

# %%
# Calculate total number of reads in each sample
total_reads_CATT = CATT[['Sample','nReads_TCR','nReads_CATT']].groupby('Sample').sum().rename(columns={'nReads_TCR':'total_reads_TCR','nReads_CATT':'total_reads_CATT'})

# Merge dataframes 
CATT = pd.merge(CATT, total_reads_CATT, how='outer', on=['Sample']).fillna(0)

# Renormalize the frequency
CATT['renormalized_frequency_TCR'] = CATT['nReads_TCR'] / (CATT['total_reads_TCR'] * 1.0)
CATT['renormalized_frequency_CATT'] = CATT['nReads_CATT'] / (CATT['total_reads_CATT'] * 1.0)
CATT.fillna(0, inplace=True)

# %%
CATT_sample01 = CATT.loc[CATT['Sample'] == 'sample01']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_CATT', hue='class', s=20, data=CATT_sample01, palette=['#d65f5f'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(CATT_sample01['renormalized_frequency_TCR'], CATT_sample01['renormalized_frequency_CATT'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('CATT - sample01',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8d.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8d.png",bbox_inches="tight")

plt.show()

# %%
CATT_sample02 = CATT.loc[CATT['Sample'] == 'sample02']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_CATT', hue='class', s=20, data=CATT_sample02, palette=['#d65f5f'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(CATT_sample02['renormalized_frequency_TCR'], CATT_sample02['renormalized_frequency_CATT'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('CATT - sample02',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8h.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8h.png",bbox_inches="tight")

plt.show()

# %%
CATT_sample03 = CATT.loc[CATT['Sample'] == 'sample03']
f, ax = plt.subplots(figsize=(5,5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='renormalized_frequency_TCR', y='renormalized_frequency_CATT', hue='class', s=20, data=CATT_sample03, palette=['#d65f5f'])

g = sns.lineplot(x=range(0,2),y=range(0,2),color=".7")
g.lines[0].set_linestyle("--")

ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(0.000001, 1)
plt.ylim(0.000001, 1)

r, p = stats.pearsonr(CATT_sample03['renormalized_frequency_TCR'], CATT_sample03['renormalized_frequency_CATT'])
plt.text(0.01,0.000003,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)
    
g.axes.set_title('CATT - sample03',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based TCRB clonotype frequency",fontsize=15)
g.set_ylabel("RNA-Seq-based TCRB clonotype frequency",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
g.legend_.remove()
sns.despine()

plt.savefig("../figures/supplementary/figureS8/figureS8l.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS8/figureS8l.png",bbox_inches="tight")

plt.show()
