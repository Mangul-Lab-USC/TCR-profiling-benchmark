# %%
import pandas as pd
import glob
import os
import numpy as np
from functools import reduce
import warnings
warnings.simplefilter('ignore')

# %%
data = pd.read_csv('../summary_data/original/all_tools_TRB.csv')
data
# Out:
#             Sample               CDR3  nReads_TCR  nReads_CATT  nReads_MIXCR  \
# 0       SRR5233637   CASSPRVTSGTYEQYF        32.0          0.0           0.0
# 1       SRR5233637    CASSYSDRGGQPQHF        13.0          0.0           0.0
# 2       SRR5233637     CASKVALGGETQYF        25.0          0.0           0.0
# 3       SRR5233637  CASRAPGTGTLGSPLHF        66.0          0.0           0.0
# 4       SRR5233637   CASSSGQGGPSTEAFF        52.0          0.0           0.0
# ...            ...                ...         ...          ...           ...
# 378937    sample14    CASSESPAFGEKLFF         0.0          0.0           0.0
# 378938    sample14     CASSWTGSQETQYF         0.0          0.0           0.0
# 378939    sample14   CASRTGLAGGIGELFF         0.0          0.0           0.0
# 378940    sample14       CASSVEGYEQYF         0.0          0.0           0.0
# 378941    sample14    CASSQQGDSNQPQHF         0.0          0.0           0.0
#
#         nReads_IMREP  nReads_TRUST4           tissue  tissue_type  \
# 0                0.0            0.0  small_intestine  T_cell_poor
# 1                0.0            0.0  small_intestine  T_cell_poor
# 2                0.0            0.0  small_intestine  T_cell_poor
# 3                0.0            0.0  small_intestine  T_cell_poor
# 4                0.0            0.0  small_intestine  T_cell_poor
# ...              ...            ...              ...          ...
# 378937           0.0            3.0         melanoma  T_cell_poor
# 378938           0.0            2.0         melanoma  T_cell_poor
# 378939           0.0            2.0         melanoma  T_cell_poor
# 378940           0.0            2.0         melanoma  T_cell_poor
# 378941           0.0            2.0         melanoma  T_cell_poor
#
#         total_reads_TCR  ...  total_reads_IMREP  total_reads_TRUST4  \
# 0             3047629.0  ...              315.0               544.0
# 1             3047629.0  ...              315.0               544.0
# 2             3047629.0  ...              315.0               544.0
# 3             3047629.0  ...              315.0               544.0
# 4             3047629.0  ...              315.0               544.0
# ...                 ...  ...                ...                 ...
# 378937         749686.0  ...              152.0               351.0
# 378938         749686.0  ...              152.0               351.0
# 378939         749686.0  ...              152.0               351.0
# 378940         749686.0  ...              152.0               351.0
# 378941         749686.0  ...              152.0               351.0
#
#         total_reads_CATT  frequency_TCR  frequency_MIXCR  frequency_IMREP  \
# 0                 5616.0       0.000010              0.0              0.0
# 1                 5616.0       0.000004              0.0              0.0
# 2                 5616.0       0.000008              0.0              0.0
# 3                 5616.0       0.000022              0.0              0.0
# 4                 5616.0       0.000017              0.0              0.0
# ...                  ...            ...              ...              ...
# 378937             751.0       0.000000              0.0              0.0
# 378938             751.0       0.000000              0.0              0.0
# 378939             751.0       0.000000              0.0              0.0
# 378940             751.0       0.000000              0.0              0.0
# 378941             751.0       0.000000              0.0              0.0
#
#         frequency_TRUST4  frequency_CATT  repertoire_type  \
# 0               0.000000             0.0         high_SDI
# 1               0.000000             0.0         high_SDI
# 2               0.000000             0.0         high_SDI
# 3               0.000000             0.0         high_SDI
# 4               0.000000             0.0         high_SDI
# ...                  ...             ...              ...
# 378937          0.008547             0.0         high_SDI
# 378938          0.005698             0.0         high_SDI
# 378939          0.005698             0.0         high_SDI
# 378940          0.005698             0.0         high_SDI
# 378941          0.005698             0.0         high_SDI
#
#                        class
# 0       T_cell_poor_high_SDI
# 1       T_cell_poor_high_SDI
# 2       T_cell_poor_high_SDI
# 3       T_cell_poor_high_SDI
# 4       T_cell_poor_high_SDI
# ...                      ...
# 378937  T_cell_poor_high_SDI
# 378938  T_cell_poor_high_SDI
# 378939  T_cell_poor_high_SDI
# 378940  T_cell_poor_high_SDI
# 378941  T_cell_poor_high_SDI
#
# [378942 rows x 21 columns]

# %%
def compute_frequency(samples_data, tool, discard_zero_freq_samples):

    samples = set(samples_data['Sample'])
    
    type_observed = tool
    
    data = samples_data.rename(columns={'frequency_TCR': 'frequency_truth'})
    data = data.rename(columns={'frequency_'+type_observed: 'frequency_observed'})
    data = data.rename(columns={'nReads_TCR': 'count_truth'})
    data = data.rename(columns={'nReads_'+type_observed: 'count_observed'})
    
    data = data.loc[data['frequency_truth'] > 0] #excluding clonotypes not present in ground truth

    file = open('../summary_data/original/capturing_per_class/capturing_'+type_observed+'.csv',"w")
        
    file.write("th,observed_portion_frequency\n")
    
    data_per_sample = {}

    for s in samples:
        
        data_per_sample[s] = data.loc[data['Sample'] == s, ['frequency_truth','frequency_observed','count_truth','count_observed']]

    for th in np.linspace(0., 1.0, 100000):

        s_portions = []

        for s in samples: 

            k_observed=0
            k_true=0

            s_observed=0
            s_true=0

            sample_data = data_per_sample[s]
            sample_data = sample_data.loc[sample_data['frequency_truth'] >= th]
            
            for index, cdr in sample_data.iterrows():

                freq = cdr['frequency_truth']
                
                if cdr['frequency_observed'] > 0: #check if observed sample has the clonotype
                        
                    k_observed += 1.0    #number of clonotypes with frequency greater or equal than th
                    s_observed += freq   #sum of frequencies of observed greater or equal than th
                        
                k_true += 1.0 #number of clonotypes with frequency greater or equal than th
                s_true += freq #sum of frequencies of TCR greater or equal than th

            if s_true > 0:
                s_portions.append(s_observed/s_true)
            elif discard_zero_freq_samples is False:
                s_portions.append(0.)

        file.write(str(th)+","+str(np.mean(s_portions))+"\n")

    file.close()
    print('done '+tool)

# %% [markdown]
# Discarding samples with no clonotypes from truth to compute the average portion

# %%
# T_cell_rich_low_SDI samples

T_cell_rich_low_SDI = data.loc[data['class'] == 'T_cell_rich_low_SDI']

tools = ['MIXCR', 'IMREP', 'TRUST4', 'CATT']

for tool in tools:

    compute_frequency(T_cell_rich_low_SDI, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4
# done CATT

# %%
# T_cell_rich_high_SDI samples

T_cell_rich_high_SDI = data.loc[data['class'] == 'T_cell_rich_high_SDI']

tools = ['MIXCR', 'IMREP', 'TRUST4', 'CATT']

for tool in tools:

    compute_frequency(T_cell_rich_high_SDI, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4
# done CATT

# %%
# T_cell_poor_low_SDI samples

T_cell_poor_low_SDI = data.loc[data['class'] == 'T_cell_poor_low_SDI']

tools = ['MIXCR', 'IMREP', 'TRUST4', 'CATT']

for tool in tools:

    compute_frequency(T_cell_poor_low_SDI, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4
# done CATT

# %%
# T_cell_poor_high_SDI samples

T_cell_poor_high_SDI = data.loc[data['class'] == 'T_cell_poor_high_SDI']

tools = ['MIXCR', 'IMREP', 'TRUST4', 'CATT']

for tool in tools:

    compute_frequency(T_cell_poor_high_SDI, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4
# done CATT
