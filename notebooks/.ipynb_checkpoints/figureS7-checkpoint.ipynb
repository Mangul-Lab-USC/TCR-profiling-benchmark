# %%
import seaborn as sns
import sys
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB_hill_numbers.csv")
df
# Out:
#          Sample  Q      TCR-Seq      MIXCR      IMREP     TRUST4      CATT  \
# 0    SRR5233637  1  2235.927293  21.361888  95.793333  74.406453  3.827416
# 1    SRR5233637  2   242.180124  18.967742  73.228782  46.677603  1.761968
# 2    SRR5233637  3   126.365461  17.020257  56.437131  34.833118  1.555905
# 3    SRR5233637  4    94.913610  15.537945  46.945876  29.360410  1.483632
# 4    SRR5233637  5    80.912996  14.436081  41.620965  26.327852  1.447746
# ..          ... ..          ...        ...        ...        ...       ...
# 109    sample14  2   218.974631  23.174229  26.495413  38.440250  5.447864
# 110    sample14  3   123.443766  19.493839  21.954361  32.322706  3.951427
# 111    sample14  4    95.939651  16.930215  19.176740  28.802063  3.461800
# 112    sample14  5    83.036930  15.246426  17.431279  26.588053  3.220967
# 113    sample14  6    75.413356  14.122250  16.263273  25.075847  3.078848
#
# ...

# %% [markdown]
# ## sample01

# %%
sample01 = df.loc[(df['Sample'] == 'sample01')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample01['Q'],sample01['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample01['Q'],sample01['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample01['Q'],sample01['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample01['Q'],sample01['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample01['Q'],sample01['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample01',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7a.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7a.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample02

# %%
sample02 = df.loc[(df['Sample'] == 'sample02')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample02['Q'],sample02['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample02['Q'],sample02['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample02['Q'],sample02['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample02['Q'],sample02['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample02['Q'],sample02['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample02',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7b.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7b.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample03

# %%
sample03 = df.loc[(df['Sample'] == 'sample03')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample03['Q'],sample03['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample03['Q'],sample03['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample03['Q'],sample03['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample03['Q'],sample03['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample03['Q'],sample03['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample03',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7c.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7c.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample13

# %%
sample13 = df.loc[(df['Sample'] == 'sample13')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample13['Q'],sample13['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample13['Q'],sample13['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample13['Q'],sample13['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample13['Q'],sample13['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample13['Q'],sample13['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample13',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7d.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7d.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample04

# %%
sample04 = df.loc[(df['Sample'] == 'sample04')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample04['Q'],sample04['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample04['Q'],sample04['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample04['Q'],sample04['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample04['Q'],sample04['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample04['Q'],sample04['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample04',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7e.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7e.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample05

# %%
sample05 = df.loc[(df['Sample'] == 'sample05')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample05['Q'],sample05['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample05['Q'],sample05['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample05['Q'],sample05['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample05['Q'],sample05['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample05['Q'],sample05['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample05',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7f.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7f.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## SRR5233639

# %%
SRR5233639 = df.loc[(df['Sample'] == 'SRR5233639')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(SRR5233639['Q'],SRR5233639['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(SRR5233639['Q'],SRR5233639['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(SRR5233639['Q'],SRR5233639['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(SRR5233639['Q'],SRR5233639['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(SRR5233639['Q'],SRR5233639['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('SRR5233639',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7g.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7g.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample06

# %%
sample06 = df.loc[(df['Sample'] == 'sample06')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample06['Q'],sample06['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample06['Q'],sample06['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample06['Q'],sample06['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample06['Q'],sample06['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample06['Q'],sample06['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample06',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7h.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7h.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample07

# %%
sample07 = df.loc[(df['Sample'] == 'sample07')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample07['Q'],sample07['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample07['Q'],sample07['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample07['Q'],sample07['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample07['Q'],sample07['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample07['Q'],sample07['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample07',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7i.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7i.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample08

# %%
sample08 = df.loc[(df['Sample'] == 'sample08')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample08['Q'],sample08['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample08['Q'],sample08['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample08['Q'],sample08['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample08['Q'],sample08['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample08['Q'],sample08['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample08',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7j.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7j.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample09

# %%
sample09 = df.loc[(df['Sample'] == 'sample09')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample09['Q'],sample09['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample09['Q'],sample09['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample09['Q'],sample09['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample09['Q'],sample09['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample09['Q'],sample09['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample09',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7k.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7k.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample10

# %%
sample10 = df.loc[(df['Sample'] == 'sample10')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample10['Q'],sample10['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample10['Q'],sample10['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample10['Q'],sample10['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample10['Q'],sample10['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample10['Q'],sample10['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample10',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7l.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7l.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample11

# %%
sample11 = df.loc[(df['Sample'] == 'sample11')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample11['Q'],sample11['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample11['Q'],sample11['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample11['Q'],sample11['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample11['Q'],sample11['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample11['Q'],sample11['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample11',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7m.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7m.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample12

# %%
sample12 = df.loc[(df['Sample'] == 'sample12')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample12['Q'],sample12['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample12['Q'],sample12['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample12['Q'],sample12['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample12['Q'],sample12['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample12['Q'],sample12['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample12',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7n.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7n.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample14

# %%
sample14 = df.loc[(df['Sample'] == 'sample14')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(sample14['Q'],sample14['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(sample14['Q'],sample14['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(sample14['Q'],sample14['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(sample14['Q'],sample14['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(sample14['Q'],sample14['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('sample14',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7o.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7o.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## SRR5233637

# %%
SRR5233637 = df.loc[(df['Sample'] == 'SRR5233637')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(SRR5233637['Q'],SRR5233637['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(SRR5233637['Q'],SRR5233637['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(SRR5233637['Q'],SRR5233637['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(SRR5233637['Q'],SRR5233637['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(SRR5233637['Q'],SRR5233637['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('SRR5233637',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7p.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7p.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TCGA-CZ-4862

# %%
df_4862 = df.loc[(df['Sample'] == 'TCGA-CZ-4862')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_4862['Q'],df_4862['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(df_4862['Q'],df_4862['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(df_4862['Q'],df_4862['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(df_4862['Q'],df_4862['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(df_4862['Q'],df_4862['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('TCGA-CZ-4862',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7q.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7q.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TCGA-CZ-5463

# %%
df_5463 = df.loc[(df['Sample'] == 'TCGA-CZ-5463')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_5463['Q'],df_5463['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(df_5463['Q'],df_5463['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(df_5463['Q'],df_5463['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(df_5463['Q'],df_5463['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(df_5463['Q'],df_5463['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('TCGA-CZ-5463',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7r.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7r.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TCGA-CZ-5985

# %%
df_5985 = df.loc[(df['Sample'] == 'TCGA-CZ-5985')]

sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_5985['Q'],df_5985['TCR-Seq'],label='TCR-Seq',color='#956cb4',marker="o")
sns.lineplot(df_5985['Q'],df_5985['MIXCR'],label='MIXCR',color='#4878d0',marker="o")
sns.lineplot(df_5985['Q'],df_5985['IMREP'],label='IMREP',color='#ee854a',marker="o")
sns.lineplot(df_5985['Q'],df_5985['TRUST4'],label='TRUST4',color='#6acc64',marker="o")
sns.lineplot(df_5985['Q'],df_5985['CATT'],label='CATT',color='#d65f5f',marker="o")
    
ax.legend(['TCR-Seq','MIXCR','IMREP','TRUST4','CATT'])
  
plt.legend(bbox_to_anchor=(0.3,1), frameon=False, ncol=2, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Diversity estimation')
ax.set_xlabel('Q value')
plt.title('TCGA-CZ-5985',y=1.05,fontsize=15)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS7/figureS7s.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS7/figureS7s.png",bbox_inches="tight")

plt.show()
