# %%
import pandas as pd
import glob
import os
import numpy as np
from functools import reduce
import warnings
warnings.simplefilter('ignore')

# %%
data = pd.read_csv('../summary_data/75bp/all_tools_TRB.csv')
data
# Out:
#          Sample                 CDR3  nReads_TCR  nReads_MIXCR  nReads_IMREP  \
# 0      sample01       CAWRGDTAQQPQHF         2.0           0.0           0.0
# 1      sample01        CASSRDSPETQYF         2.0           0.0           0.0
# 2      sample01    CASSYSGRALGTGELFF         2.0           0.0           0.0
# 3      sample01      CASSPDGGLRSPLHF         2.0           0.0           0.0
# 4      sample01    CASTPRGTVTSNQPQHF         4.0           0.0           4.0
# ...         ...                  ...         ...           ...           ...
# 55392  sample05     CASSQEPSGDYNEQFF         0.0           0.0           4.0
# 55393  sample05       CASSLHGGAGEQYF         0.0           0.0           2.0
# 55394  sample05  CASVRESSPKREINVKAFF         0.0           0.0           2.0
# 55395  sample05     CASSLEGRTTAETQYF         0.0           0.0           6.0
# 55396  sample05        CASSLLGRYEQYF         0.0           0.0           2.0
#
#        nReads_TRUST4 tissue  tissue_type  total_reads_TCR  total_reads_MIXCR  \
# 0                0.0   PBMC  T_cell_rich          90577.0           147531.0
# 1                0.0   PBMC  T_cell_rich          90577.0           147531.0
# 2                0.0   PBMC  T_cell_rich          90577.0           147531.0
# 3                0.0   PBMC  T_cell_rich          90577.0           147531.0
# 4                2.0   PBMC  T_cell_rich          90577.0           147531.0
# ...              ...    ...          ...              ...                ...
# 55392            0.0   PBMC  T_cell_rich          18617.0               48.0
# 55393            0.0   PBMC  T_cell_rich          18617.0               48.0
# 55394            0.0   PBMC  T_cell_rich          18617.0               48.0
# 55395            0.0   PBMC  T_cell_rich          18617.0               48.0
# 55396            0.0   PBMC  T_cell_rich          18617.0               48.0
#
#        total_reads_IMREP  total_reads_TRUST4  frequency_TCR  frequency_MIXCR  \
# 0               101887.0             41094.0       0.000022              0.0
# 1               101887.0             41094.0       0.000022              0.0
# 2               101887.0             41094.0       0.000022              0.0
# 3               101887.0             41094.0       0.000022              0.0
# 4               101887.0             41094.0       0.000044              0.0
# ...                  ...                 ...            ...              ...
# 55392               88.0                 0.0       0.000000              0.0
# 55393               88.0                 0.0       0.000000              0.0
# 55394               88.0                 0.0       0.000000              0.0
# 55395               88.0                 0.0       0.000000              0.0
# 55396               88.0                 0.0       0.000000              0.0
#
#        frequency_IMREP  frequency_TRUST4 repertoire_type  \
# 0             0.000000          0.000000      monoclonal
# 1             0.000000          0.000000      monoclonal
# 2             0.000000          0.000000      monoclonal
# 3             0.000000          0.000000      monoclonal
# 4             0.000039          0.000049      monoclonal
# ...                ...               ...             ...
# 55392         0.045455          0.000000      polyclonal
# 55393         0.022727          0.000000      polyclonal
# 55394         0.022727          0.000000      polyclonal
# 55395         0.068182          0.000000      polyclonal
# 55396         0.022727          0.000000      polyclonal
#
#                         class
# 0      T_cell_rich_monoclonal
# 1      T_cell_rich_monoclonal
# 2      T_cell_rich_monoclonal
# 3      T_cell_rich_monoclonal
# 4      T_cell_rich_monoclonal
# ...                       ...
# 55392  T_cell_rich_polyclonal
# 55393  T_cell_rich_polyclonal
# 55394  T_cell_rich_polyclonal
# 55395  T_cell_rich_polyclonal
# 55396  T_cell_rich_polyclonal
#
# [55397 rows x 18 columns]

# %%
def compute_frequency(samples_data, tool, discard_zero_freq_samples):

    samples = set(samples_data['Sample'])
    
    type_observed = tool
    
    data = samples_data.rename(columns={'frequency_TCR': 'frequency_truth'})
    data = data.rename(columns={'frequency_'+type_observed: 'frequency_observed'})
    data = data.rename(columns={'nReads_TCR': 'count_truth'})
    data = data.rename(columns={'nReads_'+type_observed: 'count_observed'})
    
    data = data.loc[data['frequency_truth'] > 0] #excluding clonotypes not present in ground truth

    file = open('../summary_data/75bp/capturing_per_class/capturing_'+type_observed+'.csv',"w")
        
    file.write("th,observed_portion_frequency\n")
    
    data_per_sample = {}

    for s in samples:
        
        data_per_sample[s] = data.loc[data['Sample'] == s, ['frequency_truth','frequency_observed','count_truth','count_observed']]

    for th in np.linspace(0., 1.0, 100000):

        s_portions = []

        for s in samples: 

            k_observed=0
            k_true=0

            s_observed=0
            s_true=0

            sample_data = data_per_sample[s]
            sample_data = sample_data.loc[sample_data['frequency_truth'] >= th]
            
            for index, cdr in sample_data.iterrows():

                freq = cdr['frequency_truth']
                
                if cdr['frequency_observed'] > 0: #check if observed sample has the clonotype
                        
                    k_observed += 1.0    #number of clonotypes with frequency greater or equal than th
                    s_observed += freq   #sum of frequencies of observed greater or equal than th
                        
                k_true += 1.0 #number of clonotypes with frequency greater or equal than th
                s_true += freq #sum of frequencies of TCR greater or equal than th

            if s_true > 0:
                s_portions.append(s_observed/s_true)
            elif discard_zero_freq_samples is False:
                s_portions.append(0.)

        file.write(str(th)+","+str(np.mean(s_portions))+"\n")

    file.close()
    print('done '+tool)

# %% [markdown]
# Discarding samples with no clonotypes from truth to compute the average portion

# %%
# T_cell_rich_monoclonal samples

T_cell_rich_monoclonal = data.loc[data['class'] == 'T_cell_rich_monoclonal']

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(T_cell_rich_monoclonal, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4

# %%
# T_cell_rich_polyclonal samples

T_cell_rich_polyclonal = data.loc[data['class'] == 'T_cell_rich_polyclonal']

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(T_cell_rich_polyclonal, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4
