# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB.csv")
df = df.loc[~(df['frequency_TCR'] == 0)]
df
# Out:
#             Sample               CDR3  nReads_TCR  nReads_MIXCR  nReads_IMREP  \
# 0       SRR5233637   CASSPRVTSGTYEQYF        32.0           0.0           0.0
# 1       SRR5233637    CASSYSDRGGQPQHF        13.0           0.0           0.0
# 2       SRR5233637     CASKVALGGETQYF        25.0           0.0           0.0
# 3       SRR5233637  CASRAPGTGTLGSPLHF        66.0           0.0           0.0
# 4       SRR5233637   CASSSGQGGPSTEAFF        52.0           0.0           0.0
# ...            ...                ...         ...           ...           ...
# 375300    sample14   CASSPRVAIVYNEQFF         4.0           0.0           0.0
# 375301    sample14      CASSYRQSGELFF        77.0           0.0           0.0
# 375302    sample14   CASSQGGSGGPGELFF        48.0           0.0           0.0
# 375303    sample14  CASSVSSGGFREVEQYF        15.0           0.0           0.0
# 375304    sample14    CAWSVRPGGDTEAFF        10.0           0.0           0.0
#
# ...

# %%
# Define clonotype groups based on frequency
def clonotype_group (row):
    if row['frequency_TCR'] > 0.01 and row['frequency_TCR'] <= 1:
        return 'Hyperexpanded'
    if row['frequency_TCR'] > 0.001 and row['frequency_TCR'] <= 0.01: 
        return 'Large'
    if row['frequency_TCR'] > 0.0001 and row['frequency_TCR'] <= 0.001:
        return 'Medium'
    if row['frequency_TCR'] > 0.00001 and row['frequency_TCR'] <= 0.0001:
        return 'Small'
    if row['frequency_TCR'] > 0 and row['frequency_TCR'] <= 0.00001:
        return 'Rare'

# Apply the clonotype_group function to the dataframe
df['clonotype_group'] = df.apply (lambda row: clonotype_group(row),axis=1)

# %%
TCR_abundance = df.groupby(['Sample','class','tissue_type','repertoire_type','clonotype_group']).agg({'frequency_TCR':'sum'}).reset_index().rename(columns={'frequency_TCR':"clonotype_abundance"})
TCR_abundance.loc[:,'clonotype_abundance'] = TCR_abundance['clonotype_abundance']*100
TCR_abundance
# Out:
#         Sample                   class  tissue_type repertoire_type  \
# 0   SRR5233637  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 1   SRR5233637  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 2   SRR5233637  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 3   SRR5233637  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 4   SRR5233637  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# ..         ...                     ...          ...             ...
# 73    sample14  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 74    sample14  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 75    sample14  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 76    sample14  T_cell_poor_polyclonal  T_cell_poor      polyclonal
# 77    sample14  T_cell_poor_polyclonal  T_cell_poor      polyclonal
#
#    clonotype_group  clonotype_abundance
# 0    Hyperexpanded            14.948539
# 1            Large            29.978091
# ...

# %%
mean1 = TCR_abundance.groupby(["repertoire_type",'clonotype_group'])["clonotype_abundance"].agg(["mean", "std"]) 
display(mean1)
# Out:
#                                       mean        std
# repertoire_type clonotype_group
# monoclonal      Hyperexpanded    90.170577   1.914452
#                 Large             6.332581   8.140707
#                 Medium            0.744053   0.309850
#                 Rare              4.699741        NaN
#                 Small             6.325526   3.607847
# polyclonal      Hyperexpanded    20.816665  20.309387
#                 Large            20.626082   7.745101
#                 Medium           39.230595  19.600196
#                 Rare              4.793096   9.342445
#                 Small            27.456015  17.752945

# %% [markdown]
# ## sample01

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample01 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample01']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample01, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample01',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_a1.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_a1.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample02

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample02 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample02']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample02, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample02',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_a2.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_a2.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample03

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample03 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample03']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample03, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample03',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_a3.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_a3.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample13

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample13 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample13']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample13, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample13',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_a4.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_a4.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample04

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample04 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample04']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample04, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample04',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b1.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b1.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample05

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample05 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample05']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample05, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample05',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b2.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b2.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample06

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample06 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample06']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample06, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample06',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b3.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b3.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample07

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample07 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample07']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample07, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample07',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b4.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b4.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample08

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample08 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample08']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample08, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample08',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b5.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b5.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample09

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample09 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample09']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample09, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample09',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b6.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b6.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample10

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample10 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample10']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample10, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample10',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b7.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b7.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample11

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample11 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample11']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample11, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample11',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b8.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b8.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample12

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample12 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample12']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample12, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample12',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b9.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b9.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## sample14

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_sample14 = TCR_abundance.loc[TCR_abundance['Sample'] == 'sample14']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_sample14, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('sample14',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b10.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b10.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## SRR5233639

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_SRR5233639 = TCR_abundance.loc[TCR_abundance['Sample'] == 'SRR5233639']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_SRR5233639, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('SRR5233639',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b11.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b11.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## SRR5233637

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_SRR5233637 = TCR_abundance.loc[TCR_abundance['Sample'] == 'SRR5233637']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_SRR5233637, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('SRR5233637',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b12.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b12.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## TCGA-CZ-4862

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_4862 = TCR_abundance.loc[TCR_abundance['Sample'] == 'TCGA-CZ-4862']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_4862, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('TCGA-CZ-4862',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b13.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b13.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## TCGA-CZ-5463

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_5463 = TCR_abundance.loc[TCR_abundance['Sample'] == 'TCGA-CZ-5463']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_5463, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('TCGA-CZ-5463',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b14.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b14.png",bbox_inches="tight")
plt.show(block=False)

# %% [markdown]
# ## TCGA-CZ-5985

# %%
label_order = ['Hyperexpanded','Large','Medium','Small','Rare']
palette = sns.color_palette("muted")
palette.reverse()

df_5985 = TCR_abundance.loc[TCR_abundance['Sample'] == 'TCGA-CZ-5985']

plt.figure(figsize=(5,5))
ax = sns.barplot(x='clonotype_group', y='clonotype_abundance', data=df_5985, order=label_order, palette=palette)
ax.set_xlabel('Clonotype group',fontsize=16)
ax.set_ylabel('Clonotype abundance (%)',fontsize=16)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0,100)
plt.title('TCGA-CZ-5985',y=1.1,fontsize=16)
plt.xticks(fontsize=13,rotation=45)
plt.yticks(fontsize=13)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10_b15.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10_b15.png",bbox_inches="tight")
plt.show(block=False)

# %%
TCR = df.groupby(['Sample','class','tissue_type','repertoire_type','clonotype_group']).size().reset_index(name='clonotype_group_count')

# %%
mean2 = TCR.groupby(["repertoire_type",'clonotype_group'])["clonotype_group_count"].agg(["mean", "std"]) 
display(mean2)
# Out:
#                                          mean           std
# repertoire_type clonotype_group
# monoclonal      Hyperexpanded        1.000000      0.000000
#                 Large                1.000000           NaN
#                 Medium              43.000000     17.349352
#                 Rare              6713.000000           NaN
#                 Small             2360.333333   1229.952980
# polyclonal      Hyperexpanded        6.500000      4.066120
#                 Large               78.941176     30.038456
#                 Medium            1728.187500   1338.143850
#                 Rare             22003.300000  59408.363887
#                 Small             8727.416667   6702.963272
