# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np

# %%
df = pd.read_csv("../summary_data/150bp/all_tools_TRB.csv")
df
# Out:
#                     Sample                CDR3  nReads_TCR  nReads_MIXCR  \
# 0        MP-11-28-12RNA_S2       CASSETGAETQYF         4.0           0.0
# 1        MP-11-28-12RNA_S2     CASSFETVNNSPLHF         2.0           0.0
# 2        MP-11-28-12RNA_S2    CAISESGGSSYNEQFF         2.0           0.0
# 3        MP-11-28-12RNA_S2     CASSVSYRGRFGYTF         4.0           0.0
# 4        MP-11-28-12RNA_S2       CASTRWGDNEQFF         2.0           0.0
# ...                    ...                 ...         ...           ...
# 151597  SAR-11-14-12RNA_S1  CASSEWGPGTGDSYEQYF         0.0           0.0
# 151598  SAR-11-14-12RNA_S1      CASSVPGQGSSMYF         0.0           0.0
# 151599  SAR-11-14-12RNA_S1        CASSPRGDEQFF         0.0           0.0
# 151600  SAR-11-14-12RNA_S1      CASSLASVLQPQHF         0.0           0.0
# 151601  SAR-11-14-12RNA_S1     CASSSRLAGTDTQYF         0.0           0.0
#
#         nReads_IMREP  nReads_TRUST4 sample_type  total_reads_TCR  \
# ...

# %%
skin_samples = df.loc[((df['sample_type'] == 'melanoma'))]
skin_samples
# Out:
#                       Sample               CDR3  nReads_TCR  nReads_MIXCR  \
# 5482   CMT-baseline1C_CAGATC  CASRGGGDRGTNYGYTF        72.0           0.0
# 5483   CMT-baseline1C_CAGATC      CASSVGGNTEAFF       137.0           0.0
# 5484   CMT-baseline1C_CAGATC  CASSVFEPASSYNEQFF         5.0           0.0
# 5485   CMT-baseline1C_CAGATC   CASSVGEQGLNQPQHF       973.0           0.0
# 5486   CMT-baseline1C_CAGATC     CASSRGPTNEKLFF       122.0           0.0
# ...                      ...                ...         ...           ...
# 81676    RAS-baseline_TGACCA     CASSPPLVRDEQYF         0.0           0.0
# 81677    RAS-baseline_TGACCA    CASSQQGDSNQPQHF         0.0           0.0
# 81678    RAS-baseline_TGACCA   CASRTGLAGGIGELFF         0.0           0.0
# 81679    RAS-baseline_TGACCA       CASSVEGYEQYF         0.0           0.0
# 81680    RAS-baseline_TGACCA    CASSESPAFGEKLFF         0.0           0.0
#
#        nReads_IMREP  nReads_TRUST4 sample_type  total_reads_TCR  \
# ...

# %%
major = skin_samples.loc[((skin_samples['frequency_TCR'] >= 0.01))]
major
# Out:
#                       Sample               CDR3  nReads_TCR  nReads_MIXCR  \
# 12536  CMT-baseline1C_CAGATC    CAISDSGTSNTEAFF     10391.0           4.0
# 15604    LEK-baseline_CGATGT    CASSQGEGPGQPQHF     56538.0           0.0
# 21571    LEK-baseline_CGATGT      CASSPTGSTEAFF     76340.0           2.0
# 21994    LEK-baseline_CGATGT     CASTHPGGIYGYTF     20684.0           0.0
# 22283    LEK-baseline_CGATGT  CASSQDYGQGVGNTIYF     50370.0           0.0
# ...                      ...                ...         ...           ...
# 79796    RAS-baseline_TGACCA    CASSVHTGPSYEQYF     11288.0           0.0
# 80043    RAS-baseline_TGACCA      CASSPFNNNEQFF      8567.0           7.0
# 80473    RAS-baseline_TGACCA       CASSQGQDEQYF     10977.0           0.0
# 80618    RAS-baseline_TGACCA        CASSLGDTQYF     13246.0           9.0
# 81018    RAS-baseline_TGACCA   CASSLTSGTGLYEQYF     16516.0          12.0
#
#        nReads_IMREP  nReads_TRUST4 sample_type  total_reads_TCR  \
# ...

# %%
# Count the number of clonotypes that are captured by RNA-Seq in each sample

# TCR 
TCR = major.groupby('Sample')['frequency_TCR'].count().reset_index().rename(columns={'frequency_TCR':'count_TCR'})

# MIXCR
MIXCR = major[major['frequency_MIXCR'] != 0].groupby('Sample')['frequency_MIXCR'].count().reset_index().rename(columns={'frequency_MIXCR':'count_tool'})
MIXCR = pd.merge(TCR, MIXCR, how='outer', on=['Sample']).fillna(0)
MIXCR['tool'] = 'MIXCR'

# IMREP
IMREP = major[major['frequency_IMREP'] != 0].groupby('Sample')['frequency_IMREP'].count().reset_index().rename(columns={'frequency_IMREP':'count_tool'})
IMREP = pd.merge(TCR, IMREP, how='outer', on=['Sample']).fillna(0)
IMREP['tool'] = 'IMREP'

# TRUST4
TRUST4 = major[major['frequency_TRUST4'] != 0].groupby('Sample')['frequency_TRUST4'].count().reset_index().rename(columns={'frequency_TRUST4':'count_tool'})
TRUST4 = pd.merge(TCR, TRUST4, how='outer', on=['Sample']).fillna(0)
TRUST4['tool'] = 'TRUST4'

overlap_count = pd.concat([MIXCR,IMREP,TRUST4],ignore_index=True)
overlap_count['overlap_percentage'] = overlap_count['count_tool']/overlap_count['count_TCR']*100

overlap_count
# Out:
#                     Sample  count_TCR  count_tool    tool  overlap_percentage
# 0    CMT-baseline1C_CAGATC          1         1.0   MIXCR          100.000000
# 1     HM-baseline1C_CGATGT          6         0.0   MIXCR            0.000000
# 2   JSSBaseline-RNA_GTGAAA          3         0.0   MIXCR            0.000000
# 3     LEK-OT110712A_CCGTCC          8         6.0   MIXCR           75.000000
# 4      LEK-baseline_CGATGT         11         4.0   MIXCR           36.363636
# 5              PT0112-B_S3          4         0.0   MIXCR            0.000000
# 6              PT0285-B_S5          7         1.0   MIXCR           14.285714
# 7                PT0310_S9         10         2.0   MIXCR           20.000000
# 8      RAS-baseline_TGACCA         13         6.0   MIXCR           46.153846
# 9    CMT-baseline1C_CAGATC          1         1.0   IMREP          100.000000
# 10    HM-baseline1C_CGATGT          6         0.0   IMREP            0.000000
# ...

# %%
overlap_count['overlap_percentage'].mean()
# Out:
# 35.976276809610155

# %%
tools = ['MIXCR','IMREP','TRUST4']              
for tool in tools:  
    print(tool)
    df_tool = overlap_count.loc[overlap_count['tool'] == tool]
    mean_overlap_count = df_tool['overlap_percentage'].mean()
    display(mean_overlap_count)
# Out:
# MIXCR
# 32.42257742257742
# IMREP
# 36.055056055056056
# TRUST4
# 39.45119695119695

# %%
ax = sns.barplot(x='tool',y='overlap_percentage',data=overlap_count)

ax.set_xlabel('tool',fontsize=10)
ax.set_ylabel('clonotype detection percentage',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
