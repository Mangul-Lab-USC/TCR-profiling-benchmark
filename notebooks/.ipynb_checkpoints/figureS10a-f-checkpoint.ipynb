# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import pandas as pd
import numpy as np

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB.csv")
df = df.loc[~(df['frequency_TCR'] == 0)]
df2 = pd.read_csv("../summary_data/original/all_tools_TRB_diversity.csv")

# %%
## Calculate TCR-Seq confirmed clonotypes

# MIXCR
MIXCR = df[df.nReads_MIXCR != 0]
clonotype_count_MIXCR = MIXCR.groupby(['Sample'], sort=False).size().reset_index(name='confirmed_clonotype_count_tool')
clonotype_count_MIXCR['tool'] = 'MIXCR'

# IMREP
IMREP = df[df.nReads_IMREP != 0]
clonotype_count_IMREP = IMREP.groupby(['Sample'], sort=False).size().reset_index(name='confirmed_clonotype_count_tool')
clonotype_count_IMREP['tool'] = 'IMREP'

# TRUST4
TRUST4 = df[df.nReads_TRUST4 != 0]
clonotype_count_TRUST4 = TRUST4.groupby(['Sample'], sort=False).size().reset_index(name='confirmed_clonotype_count_tool')
clonotype_count_TRUST4['tool'] = 'TRUST4'

# CATT
CATT = df[df.nReads_CATT != 0]
clonotype_count_CATT = CATT.groupby(['Sample'], sort=False).size().reset_index(name='confirmed_clonotype_count_tool')
clonotype_count_CATT['tool'] = 'CATT'

confirmed_clonotype_count = pd.concat([clonotype_count_MIXCR,clonotype_count_IMREP,clonotype_count_TRUST4,clonotype_count_CATT])
clonotype_count = df2[['Sample','tissue','class','clonotype_count_tool','tool']]
clonotype = pd.merge(confirmed_clonotype_count, clonotype_count, how='inner', on=['Sample','tool'])

clonotype
# Out:
#         Sample  confirmed_clonotype_count_tool   tool           tissue  \
# 0   SRR5233637                              24  MIXCR  small_intestine
# 1   SRR5233639                             340  MIXCR       lymph_node
# 2     sample01                             473  MIXCR             PBMC
# 3     sample02                             170  MIXCR             PBMC
# 4     sample03                             307  MIXCR             PBMC
# ..         ...                             ...    ...              ...
# 67    sample10                              36   CATT         melanoma
# 68    sample11                               6   CATT         melanoma
# 69    sample12                               6   CATT         melanoma
# 70    sample13                              15   CATT         melanoma
# 71    sample14                              37   CATT         melanoma
#
#                    class  clonotype_count_tool
# 0   T_cell_poor_high_SDI                    24
# 1   T_cell_rich_high_SDI                   353
# 2    T_cell_rich_low_SDI                  2592
# 3    T_cell_rich_low_SDI                  1565
# 4    T_cell_rich_low_SDI                  1012
# ..                   ...                   ...
# 67  T_cell_poor_high_SDI                   103
# 68  T_cell_poor_high_SDI                    71
# 69  T_cell_poor_high_SDI                   105
# 70   T_cell_poor_low_SDI                   242
# 71  T_cell_poor_high_SDI                    86
#
# [72 rows x 6 columns]

# %%
mean_confirmed_clonotype = clonotype.groupby("class")["clonotype_count_tool","confirmed_clonotype_count_tool"].agg(["mean", "std"])
display(mean_confirmed_clonotype)
tools = ['MIXCR','IMREP','TRUST4','CATT']              
for tool in tools:
    print(tool)
    df_tool = clonotype.loc[clonotype['tool'] == tool]
    mean_confirmed_clonotype_tool = df_tool.groupby("class")["clonotype_count_tool","confirmed_clonotype_count_tool"].agg(["mean", "std"]) 
    display(mean_confirmed_clonotype_tool)
# Out:
#                      clonotype_count_tool               \
#                                      mean          std
# class
# T_cell_poor_high_SDI            58.045455    52.270742
# T_cell_poor_low_SDI            157.250000    65.703247
# T_cell_rich_high_SDI           690.083333   851.657897
# T_cell_rich_low_SDI           3480.166667  1239.397422
#
#                      confirmed_clonotype_count_tool
#                                                mean         std
# class
# T_cell_poor_high_SDI                      30.659091   29.999181
# T_cell_poor_low_SDI                       15.500000    1.290994
# T_cell_rich_high_SDI                     456.750000  671.706392
# T_cell_rich_low_SDI                      448.416667  161.019174
# MIXCR
#                      clonotype_count_tool              \
#                                      mean         std
# class
# T_cell_poor_high_SDI               24.875   15.084879
# T_cell_poor_low_SDI                96.000         NaN
# T_cell_rich_high_SDI              145.000  181.353246
# T_cell_rich_low_SDI              1723.000  801.762434
#
#                      confirmed_clonotype_count_tool
#                                                mean         std
# class
# T_cell_poor_high_SDI                      19.875000   13.043197
# T_cell_poor_low_SDI                       17.000000         NaN
# T_cell_rich_high_SDI                     128.333333  183.962859
# T_cell_rich_low_SDI                      316.666667  151.731122
# IMREP
#                      clonotype_count_tool               \
#                                      mean          std
# class
# T_cell_poor_high_SDI            37.583333    39.619688
# T_cell_poor_low_SDI            116.000000          NaN
# T_cell_rich_high_SDI           965.666667  1216.758124
# T_cell_rich_low_SDI           3862.333333   466.422913
#
#                      confirmed_clonotype_count_tool
#                                                mean         std
# class
# T_cell_poor_high_SDI                      25.583333   27.586091
# T_cell_poor_low_SDI                       14.000000         NaN
# T_cell_rich_high_SDI                     666.666667  975.836735
# T_cell_rich_low_SDI                      478.333333  159.678844
# TRUST4
#                      clonotype_count_tool               \
#                                      mean          std
# class
# T_cell_poor_high_SDI            66.750000    59.296060
# T_cell_poor_low_SDI            175.000000          NaN
# T_cell_rich_high_SDI          1037.666667  1192.201465
# T_cell_rich_low_SDI           4450.666667   723.176558
#
#                      confirmed_clonotype_count_tool
#                                                mean         std
# class
# T_cell_poor_high_SDI                      42.416667   39.566879
# T_cell_poor_low_SDI                       16.000000         NaN
# T_cell_rich_high_SDI                     701.000000  979.815799
# T_cell_rich_low_SDI                      538.000000  160.944090
# CATT
#                      clonotype_count_tool              \
#                                      mean         std
# class
# T_cell_poor_high_SDI            91.916667   53.467846
# T_cell_poor_low_SDI            242.000000         NaN
# T_cell_rich_high_SDI           612.000000  551.881328
# T_cell_rich_low_SDI           3884.666667  745.962689
#
#                      confirmed_clonotype_count_tool
#                                                mean         std
# class
# T_cell_poor_high_SDI                      31.166667   28.625587
# T_cell_poor_low_SDI                       15.000000         NaN
# T_cell_rich_high_SDI                     331.000000  440.809483
# T_cell_rich_low_SDI                      460.666667  168.921086

# %%
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (5,5))

ax = sns.barplot(x='class',y='clonotype_count_tool',data=clonotype,palette="muted",alpha=0.7,errwidth=2,
                 hue='tool',order=['T_cell_rich_low_SDI','T_cell_rich_high_SDI','T_cell_poor_low_SDI','T_cell_poor_high_SDI'])
sns.stripplot(x="class",y="clonotype_count_tool",data=clonotype,s=6,color=".3",palette="muted",dodge=True,linewidth=1,
              hue='tool',order=['T_cell_rich_low_SDI','T_cell_rich_high_SDI','T_cell_poor_low_SDI','T_cell_poor_high_SDI'])
ax.set(xticklabels=["rich_low_SDI", "rich_high_SDI", "poor_low_SDI", "poor_high_SDI"])

ax.set_xlabel('Sample type',fontsize=15)
ax.set_ylabel('Number of clonotypes',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=45)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:4], labels[0:4], bbox_to_anchor=(1.05, 1),frameon=False)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10a.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10a.png",bbox_inches="tight")

plt.show()

# %%
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (5,5))

ax = sns.barplot(x='class',y='confirmed_clonotype_count_tool',data=clonotype,palette="muted",alpha=0.7,errwidth=2,
                 hue='tool',order=['T_cell_rich_low_SDI','T_cell_rich_high_SDI','T_cell_poor_low_SDI','T_cell_poor_high_SDI'])
sns.stripplot(x="class",y="confirmed_clonotype_count_tool",data=clonotype,s=6,color=".3",palette="muted",dodge=True,linewidth=1,
              hue='tool',order=['T_cell_rich_low_SDI','T_cell_rich_high_SDI','T_cell_poor_low_SDI','T_cell_poor_high_SDI'])
ax.set(xticklabels=["rich_low_SDI", "rich_high_SDI", "poor_low_SDI", "poor_high_SDI"])

ax.set_xlabel('Sample type',fontsize=15)
ax.set_ylabel('Number of TCR-Seq confirmed clonotypes',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=45)
handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:4], labels[0:4], bbox_to_anchor=(1.05, 1),frameon=False)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()

plt.savefig("../figures/supplementary/figureS10/figureS10b.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10b.png",bbox_inches="tight")

plt.show()

# %%
ax = plt.subplots(figsize = (5,5))

MIXCR_figure = MIXCR.loc[MIXCR['class'] == 'T_cell_rich_low_SDI']
MIXCR_list = MIXCR_figure['CDR3'].tolist()
print('MIXCR: ', len(MIXCR_list))
IMREP_figure = IMREP.loc[IMREP['class'] == 'T_cell_rich_low_SDI']
IMREP_list = IMREP_figure['CDR3'].tolist()
print('IMREP: ', len(IMREP_list))
TRUST4_figure = TRUST4.loc[TRUST4['class'] == 'T_cell_rich_low_SDI']
TRUST4_list = TRUST4_figure['CDR3'].tolist()
print('TRUST4: ', len(TRUST4_list))

out = venn3([set(MIXCR_list), set(IMREP_list), set(TRUST4_list)], set_labels=('MIXCR','IMREP','TRUST4'), 
            set_colors=['#4878d0','#ee854a','#6acc64'],alpha=0.5)
plt.title('T cell rich low SDI samples')
for text in out.set_labels:
    text.set_fontsize(15)

for text in out.subset_labels:
    text.set_fontsize(13)
    
plt.savefig("../figures/supplementary/figureS10/figureS10c.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10c.png",bbox_inches="tight")

plt.show()
# Out:
# MIXCR:  950
# IMREP:  1435
# TRUST4:  1614

# %%
ax = plt.subplots(figsize = (5,5))

IMREP_figure = IMREP.loc[IMREP['class'] == 'T_cell_rich_low_SDI']
IMREP_list = IMREP_figure['CDR3'].tolist()
print('IMREP: ', len(IMREP_list))
TRUST4_figure = TRUST4.loc[TRUST4['class'] == 'T_cell_rich_low_SDI']
TRUST4_list = TRUST4_figure['CDR3'].tolist()
print('TRUST4: ', len(TRUST4_list))
CATT_figure = CATT.loc[CATT['class'] == 'T_cell_rich_low_SDI']
CATT_list = CATT_figure['CDR3'].tolist()
print('CATT: ', len(CATT_list))

out = venn3([set(IMREP_list), set(TRUST4_list), set(CATT_list)], set_labels=('IMREP','TRUST4','CATT'),
            set_colors=['#ee854a','#6acc64','#d65f5f'],alpha=0.5)
plt.title('T cell rich low SDI samples')
for text in out.set_labels:
    text.set_fontsize(15)

for text in out.subset_labels:
    text.set_fontsize(13)
    
plt.savefig("../figures/supplementary/figureS10/figureS10d.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10d.png",bbox_inches="tight")

plt.show()
# Out:
# IMREP:  1435
# TRUST4:  1614
# CATT:  1382

# %%
ax = plt.subplots(figsize = (5,5))

MIXCR_figure = MIXCR.loc[MIXCR['class'] == 'T_cell_rich_high_SDI']
MIXCR_list = MIXCR_figure['CDR3'].tolist()
print('MIXCR: ', len(MIXCR_list))
IMREP_figure = IMREP.loc[IMREP['class'] == 'T_cell_rich_high_SDI']
IMREP_list = IMREP_figure['CDR3'].tolist()
print('IMREP: ', len(IMREP_list))
TRUST4_figure = TRUST4.loc[TRUST4['class'] == 'T_cell_rich_high_SDI']
TRUST4_list = TRUST4_figure['CDR3'].tolist()
print('TRUST4: ', len(TRUST4_list))

out = venn3([set(MIXCR_list), set(IMREP_list), set(TRUST4_list)], set_labels=('MIXCR','IMREP','TRUST4'),
           set_colors=['#4878d0','#ee854a','#6acc64'],alpha=0.5)
plt.title('T cell rich high SDI samples')
for text in out.set_labels:
    text.set_fontsize(15)

for text in out.subset_labels:
    text.set_fontsize(13)
    
plt.savefig("../figures/supplementary/figureS10/figureS10e.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10e.png",bbox_inches="tight")

plt.show()
# Out:
# MIXCR:  385
# IMREP:  2000
# TRUST4:  2103

# %%
ax = plt.subplots(figsize = (5,5))

IMREP_figure = IMREP.loc[IMREP['class'] == 'T_cell_rich_high_SDI']
IMREP_list = IMREP_figure['CDR3'].tolist()
print('IMREP: ', len(IMREP_list))
TRUST4_figure = TRUST4.loc[TRUST4['class'] == 'T_cell_rich_high_SDI']
TRUST4_list = TRUST4_figure['CDR3'].tolist()
print('TRUST4: ', len(TRUST4_list))
CATT_figure = CATT.loc[CATT['class'] == 'T_cell_rich_high_SDI']
CATT_list = CATT_figure['CDR3'].tolist()
print('CATT: ', len(CATT_list))

out = venn3([set(IMREP_list), set(TRUST4_list), set(CATT_list)], set_labels=('IMREP','TRUST4','CATT'),
           set_colors=['#ee854a','#6acc64','#d65f5f'],alpha=0.5)
plt.title('T cell rich high SDI samples')
for text in out.set_labels:
    text.set_fontsize(15)

for text in out.subset_labels:
    text.set_fontsize(13)
    
plt.savefig("../figures/supplementary/figureS10/figureS10f.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS10/figureS10f.png",bbox_inches="tight")

plt.show()
# Out:
# IMREP:  2000
# TRUST4:  2103
# CATT:  993
