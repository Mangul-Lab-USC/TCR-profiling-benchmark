# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_150bp = pd.read_csv("../summary_data/original/all_tools_TRB_diversity.csv")
df_150bp = df_150bp[['Sample','tool','SDI_absolute_error','class']]
df_150bp = df_150bp[df_150bp.tool != '0']
df_150bp['read_length'] = '150bp'

# %%
df_75bp = pd.read_csv("../summary_data/75bp/all_tools_TRB_diversity.csv")
df_75bp = df_75bp[['Sample','tool','SDI_absolute_error','class']]
df_75bp = df_75bp[df_75bp.tool != '0']
df_75bp['read_length'] = '75bp'

# %%
df_50bp = pd.read_csv("../summary_data/50bp/all_tools_TRB_diversity.csv")
df_50bp = df_50bp[['Sample','tool','SDI_absolute_error','class']]
df_50bp = df_50bp[df_50bp.tool != '0']
df_50bp['read_length'] = '50bp'

# %%
diversity_combined = pd.concat([df_150bp,df_75bp,df_50bp])
diversity_combined
# Out:
#         Sample    tool  SDI_absolute_error                 class read_length
# 0   SRR5233637   MIXCR            4.650803  T_cell_poor_high_SDI       150bp
# 1   SRR5233637   IMREP            3.150218  T_cell_poor_high_SDI       150bp
# 2   SRR5233637  TRUST4            3.402869  T_cell_poor_high_SDI       150bp
# 3   SRR5233637    CATT            6.370222  T_cell_poor_high_SDI       150bp
# 4   SRR5233639   MIXCR            4.580975  T_cell_rich_high_SDI       150bp
# ..         ...     ...                 ...                   ...         ...
# 14    sample04    CATT            7.043151  T_cell_rich_high_SDI        50bp
# 15    sample05   MIXCR            6.810662  T_cell_rich_high_SDI        50bp
# 16    sample05   IMREP            5.790305  T_cell_rich_high_SDI        50bp
# 17    sample05  TRUST4            7.311968  T_cell_rich_high_SDI        50bp
# 18    sample05    CATT            5.939684  T_cell_rich_high_SDI        50bp
#
# [110 rows x 5 columns]

# %%
sns.set_style('white')
sns.set_context('talk')

figure = diversity_combined.loc[diversity_combined['class'] == 'T_cell_rich_low_SDI']
    
fig, ax = plt.subplots(figsize=(10, 10))
ax = sns.barplot(data=figure, x="tool", y="SDI_absolute_error", hue="read_length",palette="muted",
                 hue_order=["50bp","75bp","150bp"])
ax.set(ylim=(0,8))

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1), frameon=False, title='Read length')

ax.set_xlabel('Tools',fontsize=20)
ax.set_ylabel('Absolute error of SDI',fontsize=20)
plt.title('T cell rich low SDI samples',y=1,fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.setp(ax.get_legend().get_texts(), fontsize=20) 
plt.setp(ax.get_legend().get_title(), fontsize=20)
sns.despine()

plt.savefig("../figures/supplementary/figureS12/figureS12i.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS12/figureS12i.png",bbox_inches="tight")

plt.show()

# %%
sns.set_style('white')
sns.set_context('talk')

figure = diversity_combined.loc[diversity_combined['class'] == 'T_cell_rich_high_SDI']
    
fig, ax = plt.subplots(figsize=(10, 10))
ax = sns.barplot(data=figure, x="tool", y="SDI_absolute_error", hue="read_length",palette="muted",
                 hue_order=["50bp","75bp","150bp"])

ax.set(ylim=(0,8))
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1), frameon=False, title='Read length')

ax.set_xlabel('Tools',fontsize=20)
ax.set_ylabel('Absolute error of SDI',fontsize=20)
plt.title('T cell rich high SDI samples',y=1,fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.setp(ax.get_legend().get_texts(), fontsize=20) 
plt.setp(ax.get_legend().get_title(), fontsize=20)
sns.despine()

plt.savefig("../figures/supplementary/figureS12/figureS12j.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS12/figureS12j.png",bbox_inches="tight")

plt.show()

# %%
mean_diversity_combined = diversity_combined.groupby(["tool","read_length","class"])["SDI_absolute_error"].mean().reset_index()
mean_diversity_combined['read_length'] = pd.Categorical(mean_diversity_combined['read_length'],categories=['50bp','75bp','150bp'],ordered=True)
mean_diversity_combined = mean_diversity_combined.sort_values('read_length',ascending=False)
mean_diversity_combined
# Out:
#       tool read_length                 class  SDI_absolute_error
# 0     CATT       150bp  T_cell_poor_high_SDI            4.908060
# 11   IMREP       150bp   T_cell_rich_low_SDI            0.814811
# 27  TRUST4       150bp   T_cell_rich_low_SDI            0.653830
# 26  TRUST4       150bp  T_cell_rich_high_SDI            3.490319
# 25  TRUST4       150bp   T_cell_poor_low_SDI            2.534382
# 24  TRUST4       150bp  T_cell_poor_high_SDI            3.566085
# 19   MIXCR       150bp   T_cell_rich_low_SDI            0.141408
# 18   MIXCR       150bp  T_cell_rich_high_SDI            5.108813
# 17   MIXCR       150bp   T_cell_poor_low_SDI            2.223459
# 1     CATT       150bp   T_cell_poor_low_SDI            1.535505
# 16   MIXCR       150bp  T_cell_poor_high_SDI            4.794637
# 10   IMREP       150bp  T_cell_rich_high_SDI            3.559607
# 2     CATT       150bp  T_cell_rich_high_SDI            5.428275
# ...

# %%
mean_repertoire_absolute_error = mean_diversity_combined.groupby(["class","read_length"])["SDI_absolute_error"].agg(["mean", "std"])
display(mean_repertoire_absolute_error)
tools = ['MIXCR','IMREP','TRUST4','CATT']              
for tool in tools:  
    print(tool)
    df_tool = mean_diversity_combined.loc[mean_diversity_combined['tool'] == tool]
    mean_repertoire_absolute_error = df_tool.groupby(["class","read_length"])["SDI_absolute_error"].agg(["mean"]) 
    display(mean_repertoire_absolute_error)
# Out:
#                                       mean       std
# class                read_length
# T_cell_poor_high_SDI 50bp              NaN       NaN
#                      75bp              NaN       NaN
#                      150bp        4.348877  0.625434
# T_cell_poor_low_SDI  50bp              NaN       NaN
#                      75bp              NaN       NaN
#                      150bp        2.234020  0.498431
# T_cell_rich_high_SDI 50bp         6.252717  0.547642
#                      75bp         5.673687  1.145057
#                      150bp        4.396753  1.015464
# T_cell_rich_low_SDI  50bp         0.575149  0.050267
#                      75bp         0.479853  0.082489
#                      150bp        0.566670  0.293321
# MIXCR
#                                       mean
# class                read_length
# T_cell_poor_high_SDI 50bp              NaN
#                      75bp              NaN
#                      150bp        4.794637
# ...
