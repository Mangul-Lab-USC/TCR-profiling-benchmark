# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce
import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings("ignore", module="matplotlib")

# %%
df = pd.read_csv("../summary_data/subsample/subsample_complete.csv")
df = df[['Sample','CDR3','frequency_TCR','tool','new_frequency_tool','est_reads']]
df
# Out:
#                               Sample              CDR3  frequency_TCR    tool  \
# 0       ESO1-sorted-T-cells_S13_L007    CASSLSGGINEQFF       0.000022   MIXCR
# 1       ESO1-sorted-T-cells_S13_L007   CASNPLRDAYNEQFF       0.000022   MIXCR
# 2       ESO1-sorted-T-cells_S13_L007    CASSLGADGGELFF       0.000022   MIXCR
# 3       ESO1-sorted-T-cells_S13_L007   CASSQEEGLTYGYTF       0.000022   MIXCR
# 4       ESO1-sorted-T-cells_S13_L007    CASSLEPTGGKAFF       0.000022   MIXCR
# ...                              ...               ...            ...     ...
# 432640  INY2-sorted-T-cells_S15_L007    CASSYAANTGELSF       0.000000  TRUST4
# 432641  INY2-sorted-T-cells_S15_L007      CASSLTHNEQFF       0.000000  TRUST4
# 432642  INY2-sorted-T-cells_S15_L007      CASPGGHSPLHF       0.000000  TRUST4
# 432643  INY2-sorted-T-cells_S15_L007  CASIPKGGARPGEQFF       0.000000  TRUST4
# 432644  INY2-sorted-T-cells_S15_L007      CASSFSVYEQYF       0.000000  TRUST4
#
#         new_frequency_tool  est_reads
# 0                      0.0      28000
# 1                      0.0      28000
# 2                      0.0      28000
# 3                      0.0      28000
# 4                      0.0      28000
# ...                    ...        ...
# 432640                 0.0        260
# 432641                 0.0        260
# 432642                 0.0        260
# 432643                 0.0        260
# 432644                 0.0        260
#
# [432645 rows x 6 columns]

# %%
# MIXCR
MIXCR = df.loc[df['tool']=='MIXCR']
MIXCR = MIXCR.rename(columns={'new_frequency_tool':'frequency_MIXCR'})
MIXCR = MIXCR.drop('tool', axis=1)

# IMREP
IMREP = df.loc[df['tool']=='IMREP']
IMREP = IMREP.rename(columns={'new_frequency_tool':'frequency_IMREP'})
IMREP = IMREP.drop('tool', axis=1)

# TRUST4
TRUST4 = df.loc[df['tool']=='TRUST4']
TRUST4 = TRUST4.rename(columns={'new_frequency_tool':'frequency_TRUST4'})
TRUST4 = TRUST4.drop('tool', axis=1)

data = reduce(lambda  left,right: pd.merge(left,right,on=['Sample','CDR3','frequency_TCR','est_reads'], how='outer'), [MIXCR,IMREP,TRUST4])
data
# Out:
#                               Sample              CDR3  frequency_TCR  \
# 0       ESO1-sorted-T-cells_S13_L007    CASSLSGGINEQFF       0.000022
# 1       ESO1-sorted-T-cells_S13_L007   CASNPLRDAYNEQFF       0.000022
# 2       ESO1-sorted-T-cells_S13_L007    CASSLGADGGELFF       0.000022
# 3       ESO1-sorted-T-cells_S13_L007   CASSQEEGLTYGYTF       0.000022
# 4       ESO1-sorted-T-cells_S13_L007    CASSLEPTGGKAFF       0.000022
# ...                              ...               ...            ...
# 144210  INY2-sorted-T-cells_S15_L007    CASSYAANTGELSF       0.000000
# 144211  INY2-sorted-T-cells_S15_L007      CASSLTHNEQFF       0.000000
# 144212  INY2-sorted-T-cells_S15_L007      CASPGGHSPLHF       0.000000
# 144213  INY2-sorted-T-cells_S15_L007  CASIPKGGARPGEQFF       0.000000
# 144214  INY2-sorted-T-cells_S15_L007      CASSFSVYEQYF       0.000000
#
#         frequency_MIXCR  est_reads  frequency_IMREP  frequency_TRUST4
# 0                   0.0      28000              0.0               0.0
# 1                   0.0      28000              0.0               0.0
# 2                   0.0      28000              0.0               0.0
# 3                   0.0      28000              0.0               0.0
# 4                   0.0      28000              0.0               0.0
# ...                 ...        ...              ...               ...
# 144210              0.0        260              0.0               0.0
# 144211              0.0        260              0.0               0.0
# 144212              0.0        260              0.0               0.0
# 144213              0.0        260              0.0               0.0
# 144214              0.0        260              0.0               0.0
#
# [144215 rows x 7 columns]

# %%
def compute_frequency(samples_data, tool, discard_zero_freq_samples):

    samples = set(samples_data['Sample'])
    
    type_observed = tool
    
    data = samples_data.rename(columns={'frequency_TCR': 'frequency_truth'})
    data = data.rename(columns={'frequency_'+type_observed: 'frequency_observed'})
    
    data = data.loc[data['frequency_truth'] > 0] #excluding clonotypes not present in ground truth

    file = open('../summary_data/subsample/capturing_per_reads/capturing_'+type_observed+'.csv',"w")
        
    file.write("th,observed_portion_frequency\n")
    
    data_per_sample = {}

    for s in samples:
        
        data_per_sample[s] = data.loc[data['Sample'] == s, ['frequency_truth','frequency_observed']]

    for th in np.linspace(0., 1.0, 100000):

        s_portions = []

        for s in samples: 

            k_observed=0
            k_true=0

            s_observed=0
            s_true=0

            sample_data = data_per_sample[s]
            sample_data = sample_data.loc[sample_data['frequency_truth'] >= th]
            
            for index, cdr in sample_data.iterrows():

                freq = cdr['frequency_truth']
                
                if cdr['frequency_observed'] > 0: #check if observed sample has the clonotype
                        
                    k_observed += 1.0    #number of clonotypes with frequency greater or equal than th
                    s_observed += freq   #sum of frequencies of observed greater or equal than th
                        
                k_true += 1.0 #number of clonotypes with frequency greater or equal than th
                s_true += freq #sum of frequencies of TCR greater or equal than th

            if s_true > 0:
                s_portions.append(s_observed/s_true)
            elif discard_zero_freq_samples is False:
                s_portions.append(0.)

        file.write(str(th)+","+str(np.mean(s_portions))+"\n")

    file.close()
    print('done '+tool)

# %% [markdown]
# Discarding samples with no clonotypes from truth to compute the average portion

# %%
# est_reads = 28000

df1 = data.loc[data['est_reads'] == 28000]

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(df1, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4

# %%
# est_reads = 13500

df2 = data.loc[data['est_reads'] == 13500]

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(df2, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4

# %%
# est_reads = 2600

df3 = data.loc[data['est_reads'] == 2600]

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(df3, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4

# %%
# est_reads = 1300

df4 = data.loc[data['est_reads'] == 1300]

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(df4, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4

# %%
# est_reads = 260

df5 = data.loc[data['est_reads'] == 260]

tools = ['MIXCR', 'IMREP', 'TRUST4']

for tool in tools:

    compute_frequency(df5, tool, True)
# Out:
# done MIXCR
# done IMREP
# done TRUST4
