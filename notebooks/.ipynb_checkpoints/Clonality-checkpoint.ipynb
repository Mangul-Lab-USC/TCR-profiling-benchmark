# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB.csv")
df = df.loc[~(df['frequency_TCR'] == 0)]
df
# Out:
#                    Sample              CDR3  nReads_TCR  nReads_MIXCR  \
# 0       MP-11-28-12RNA_S2   CASSVNPGGYNEQFF         6.0           0.0
# 1       MP-11-28-12RNA_S2     CASIRTRNEKLFF         2.0           0.0
# 2       MP-11-28-12RNA_S2    CASSPGAANTEAFF         2.0           0.0
# 3       MP-11-28-12RNA_S2    CASRNQGLNTEAFF         2.0           0.0
# 4       MP-11-28-12RNA_S2  CASSLTGNRAYNEQFF         2.0           0.0
# ...                   ...               ...         ...           ...
# 389043       TCGA-CZ-5985   CASSSKTGNYNEQFF         2.0           0.0
# 389044       TCGA-CZ-5985    CASSLERLNTEAFF         3.0           0.0
# 389045       TCGA-CZ-5985     CASSIGRNTEAFF        12.0           0.0
# 389046       TCGA-CZ-5985     CASSFSAKNIQYF         2.0           0.0
# 389047       TCGA-CZ-5985  CASSLEGRSSYNEQFF        13.0           0.0
#
#         nReads_IMREP  nReads_TRUST4  tissue  tissue_type  total_reads_TCR  \
# 0                0.0            0.0    PBMC  T_cell_rich          18617.0
# 1                0.0            0.0    PBMC  T_cell_rich          18617.0
# 2                0.0            0.0    PBMC  T_cell_rich          18617.0
# 3                0.0            0.0    PBMC  T_cell_rich          18617.0
# 4                0.0            0.0    PBMC  T_cell_rich          18617.0
# ...              ...            ...     ...          ...              ...
# 389043           0.0            0.0  kidney  T_cell_poor          12998.0
# 389044           0.0            0.0  kidney  T_cell_poor          12998.0
# 389045           0.0            0.0  kidney  T_cell_poor          12998.0
# 389046           0.0            0.0  kidney  T_cell_poor          12998.0
# 389047           0.0            0.0  kidney  T_cell_poor          12998.0
#
#         total_reads_MIXCR  total_reads_IMREP  total_reads_TRUST4  \
# 0                    55.0              111.0               186.0
# 1                    55.0              111.0               186.0
# 2                    55.0              111.0               186.0
# 3                    55.0              111.0               186.0
# 4                    55.0              111.0               186.0
# ...                   ...                ...                 ...
# 389043                0.0               23.0               282.0
# 389044                0.0               23.0               282.0
# 389045                0.0               23.0               282.0
# 389046                0.0               23.0               282.0
# 389047                0.0               23.0               282.0
#
#         frequency_TCR  frequency_MIXCR  frequency_IMREP  frequency_TRUST4  \
# 0            0.000322              0.0              0.0               0.0
# 1            0.000107              0.0              0.0               0.0
# 2            0.000107              0.0              0.0               0.0
# 3            0.000107              0.0              0.0               0.0
# 4            0.000107              0.0              0.0               0.0
# ...               ...              ...              ...               ...
# 389043       0.000154              0.0              0.0               0.0
# 389044       0.000231              0.0              0.0               0.0
# 389045       0.000923              0.0              0.0               0.0
# 389046       0.000154              0.0              0.0               0.0
# 389047       0.001000              0.0              0.0               0.0
#
#        repertoire_type                   class
# 0           polyclonal  T_cell_rich_polyclonal
# 1           polyclonal  T_cell_rich_polyclonal
# 2           polyclonal  T_cell_rich_polyclonal
# 3           polyclonal  T_cell_rich_polyclonal
# 4           polyclonal  T_cell_rich_polyclonal
# ...                ...                     ...
# 389043      polyclonal  T_cell_poor_polyclonal
# 389044      polyclonal  T_cell_poor_polyclonal
# 389045      polyclonal  T_cell_poor_polyclonal
# 389046      polyclonal  T_cell_poor_polyclonal
# 389047      polyclonal  T_cell_poor_polyclonal
#
# [367786 rows x 18 columns]

# %%
# Define clonotype groups based on frequency
def clonotype_group (row):
    if row['frequency_TCR'] > 0.1 and row['frequency_TCR'] <= 1:
        return 'Hyperexpanded'
    if row['frequency_TCR'] > 0.01 and row['frequency_TCR'] <= 0.1: 
        return 'Large'
    if row['frequency_TCR'] > 0.001 and row['frequency_TCR'] <= 0.01:
        return 'Medium'
    if row['frequency_TCR'] > 0.0001 and row['frequency_TCR'] <= 0.001:
        return 'Small'
    if row['frequency_TCR'] > 0 and row['frequency_TCR'] <= 0.0001:
        return 'Rare'

# Apply the clonotype_group function to the dataframe
df['clonotype_group'] = df.apply (lambda row: clonotype_group(row),axis=1)

# %%
TCR_abundance= df.groupby(['Sample','tissue_type','repertoire_type','clonotype_group']).agg({'frequency_TCR':'sum'}).reset_index().rename(columns={'frequency_TCR':"clonotype_abundance"})
TCR_abundance.loc[:,'clonotype_abundance']=TCR_abundance['clonotype_abundance']*100
TCR_abundance
# Out:
#                           Sample  tissue_type repertoire_type clonotype_group  \
# 0          CMT-baseline1C_CAGATC  T_cell_poor      polyclonal           Large
# 1          CMT-baseline1C_CAGATC  T_cell_poor      polyclonal          Medium
# 2          CMT-baseline1C_CAGATC  T_cell_poor      polyclonal            Rare
# 3          CMT-baseline1C_CAGATC  T_cell_poor      polyclonal           Small
# 4   ESO1-sorted-T-cells_S13_L007  T_cell_rich      monoclonal   Hyperexpanded
# ..                           ...          ...             ...             ...
# 70                  TCGA-CZ-5985  T_cell_poor      polyclonal           Small
# 71                  TR2-PBMC_S12  T_cell_rich      polyclonal           Large
# 72                  TR2-PBMC_S12  T_cell_rich      polyclonal          Medium
# 73                  TR2-PBMC_S12  T_cell_rich      polyclonal            Rare
# 74                  TR2-PBMC_S12  T_cell_rich      polyclonal           Small
#
#     clonotype_abundance
# 0              1.146756
# 1             22.152119
# 2             30.486326
# 3             46.214799
# 4             90.329775
# ..                  ...
# 70            32.204955
# 71            10.849288
# 72            13.677521
# 73            45.696285
# 74            29.776905
#
# [75 rows x 5 columns]

# %%
mean = TCR_abundance.groupby(["repertoire_type",'clonotype_group'])["clonotype_abundance"].agg(["mean", "std"]) 
display(mean)
# Out:
#                                       mean        std
# repertoire_type clonotype_group
# monoclonal      Hyperexpanded    91.083285   0.706735
#                 Medium            0.576232        NaN
#                 Rare              7.892106   0.900280
#                 Small             0.832532   0.311512
# polyclonal      Hyperexpanded    40.871958  25.287962
#                 Large            14.139201  10.062124
#                 Medium           19.715157   7.692819
#                 Rare             32.970285  19.853967
#                 Small            36.217741  20.720411
