# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
est_reads = ['28000','13500','2600','1300','260']

# %% [markdown]
# MIXCR

# %%
df_MIXCR = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_MIXCR_'+reads+'.csv')
    df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
    df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)
    
    df_MIXCR = pd.merge(df_MIXCR, df_temp_aa, how='right', on=['th'])
    df_MIXCR['tool'] = 'MIXCR'

df_MIXCR
# Out:
#              th  observed_portion_frequency_28000   tool  \
# 0      0.000000                          0.922054  MIXCR
# 1      0.000010                          0.937342  MIXCR
# 2      0.000020                          0.940275  MIXCR
# 3      0.000030                          0.974777  MIXCR
# 4      0.000040                          0.985473  MIXCR
# ...         ...                               ...    ...
# 91726  0.917269                          1.000000  MIXCR
# 91727  0.917279                          1.000000  MIXCR
# 91728  0.917289                          1.000000  MIXCR
# 91729  0.917299                          1.000000  MIXCR
# 91730  0.917309                          1.000000  MIXCR
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.917583                         0.913357
# 1                              0.932869                         0.928544
# ...

# %%
# columns = ['th', 'observed_portion_frequency_aa', 'est_reads']
# df_MIXCR = pd.DataFrame(columns=columns)

# for reads in est_reads: 
#     df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_aa_ability/capturing_aa_ability_MIXCR_'+reads+'.csv')
#     df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
#     df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
#     df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_aa'}, inplace=True)

#     df_temp_aa['est_reads'] = reads
    
#     df_MIXCR = pd.concat([df_MIXCR, df_temp_aa], ignore_index=True, sort=False)
#     df_MIXCR['tool'] = 'MIXCR'

# df_MIXCR

# %% [markdown]
# IMREP

# %%
df_IMREP = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_IMREP_'+reads+'.csv')
    df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
    df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)

    df_IMREP = pd.merge(df_IMREP, df_temp_aa, how='right', on=['th'])
    df_IMREP['tool'] = 'IMREP'

df_IMREP
# Out:
#              th  observed_portion_frequency_28000   tool  \
# 0      0.000000                          0.922284  IMREP
# 1      0.000010                          0.937472  IMREP
# 2      0.000020                          0.940377  IMREP
# 3      0.000030                          0.974403  IMREP
# 4      0.000040                          0.984920  IMREP
# ...         ...                               ...    ...
# 91726  0.917269                          1.000000  IMREP
# 91727  0.917279                          1.000000  IMREP
# 91728  0.917289                          1.000000  IMREP
# 91729  0.917299                          1.000000  IMREP
# 91730  0.917309                          1.000000  IMREP
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.917800                         0.913454
# 1                              0.933052                         0.928644
# ...

# %%
# columns = ['th', 'observed_portion_frequency_aa', 'est_reads']
# df_IMREP = pd.DataFrame(columns=columns)

# for reads in est_reads: 
#     df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_aa_ability/capturing_aa_ability_IMREP_'+reads+'.csv')
#     df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
#     df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
#     df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_aa'}, inplace=True)

#     df_temp_aa['est_reads'] = reads
    
#     df_IMREP = pd.concat([df_IMREP, df_temp_aa], ignore_index=True, sort=False)
#     df_IMREP['tool'] = 'IMREP'

# df_IMREP

# %% [markdown]
# TRUST4

# %%
df_TRUST4 = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_TRUST4_'+reads+'.csv')
    df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
    df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)

    df_TRUST4 = pd.merge(df_TRUST4, df_temp_aa, how='right', on=['th'])
    df_TRUST4['tool'] = 'TRUST4'

df_TRUST4
# Out:
#              th  observed_portion_frequency_28000    tool  \
# 0      0.000000                          0.922345  TRUST4
# 1      0.000010                          0.937587  TRUST4
# 2      0.000020                          0.940536  TRUST4
# 3      0.000030                          0.974858  TRUST4
# 4      0.000040                          0.985553  TRUST4
# ...         ...                               ...     ...
# 91726  0.917269                          1.000000  TRUST4
# 91727  0.917279                          1.000000  TRUST4
# 91728  0.917289                          1.000000  TRUST4
# 91729  0.917299                          1.000000  TRUST4
# 91730  0.917309                          1.000000  TRUST4
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.918522                         0.913908
# 1                              0.933784                         0.929108
# ...

# %%
# columns = ['th', 'observed_portion_frequency_aa', 'est_reads']
# df_TRUST4 = pd.DataFrame(columns=columns)

# for reads in est_reads: 
#     df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_aa_ability/capturing_aa_ability_TRUST4_'+reads+'.csv')
#     df_temp_aa = df_temp_aa[df_temp_aa['observed_portion_frequency'].notna()]
#     df_temp_aa = df_temp_aa[df_temp_aa.observed_portion_frequency != 0]
#     df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_aa'}, inplace=True)

#     df_temp_aa['est_reads'] = reads
    
#     df_TRUST4 = pd.concat([df_TRUST4, df_temp_aa], ignore_index=True, sort=False)
#     df_TRUST4['tool'] = 'IMREP'

# df_TRUST4

# %%
df_combined = pd.concat([df_MIXCR,df_IMREP,df_TRUST4], ignore_index=True, sort=False)
df_combined
# Out:
#               th  observed_portion_frequency_28000    tool  \
# 0       0.000000                          0.922054   MIXCR
# 1       0.000010                          0.937342   MIXCR
# 2       0.000020                          0.940275   MIXCR
# 3       0.000030                          0.974777   MIXCR
# 4       0.000040                          0.985473   MIXCR
# ...          ...                               ...     ...
# 275188  0.917269                          1.000000  TRUST4
# 275189  0.917279                          1.000000  TRUST4
# 275190  0.917289                          1.000000  TRUST4
# 275191  0.917299                          1.000000  TRUST4
# 275192  0.917309                          1.000000  TRUST4
#
#         observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                               0.917583                         0.913357
# 1                               0.932869                         0.928544
# ...

# %%
tools = ['MIXCR','IMREP','TRUST4']
colors = sns.color_palette("muted")

for tool,color in zip (tools,colors):
    
    sns.set_style("white") 
    sns.set_context("talk")  
    
    figure = df_combined.loc[df_combined['tool'] == tool]
    
    fig, ax = plt.subplots(figsize=(5, 4))

    sns.lineplot(figure['th'], figure['observed_portion_frequency_260'],label='260')
    sns.lineplot(figure['th'], figure['observed_portion_frequency_1300'],label='1300')
    sns.lineplot(figure['th'], figure['observed_portion_frequency_2600'],label='2600')
    sns.lineplot(figure['th'], figure['observed_portion_frequency_13500'],label='13500')
    sns.lineplot(figure['th'], figure['observed_portion_frequency_28000'],label='28000')
    
    ax.legend(['260','1300','2600','13500','28000'])
  
    plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
    locs, labels = plt.xticks()
    ax.set_ylabel('Portion of repetoire captured by' + tool)
    ax.set_xlabel('Clonotype frequency')
    plt.title('Estimated reads',y=1.3,fontsize=16)
    ax.set_xlim(0,0.001)
    ax.set_ylim(0.98,1)

    # setting label sizes after creation
    ax.xaxis.label.set_size(16)
    ax.yaxis.label.set_size(16)
    ax.tick_params(axis='both', which='major', labelsize=13)
    ax.tick_params(axis='both', which='minor', labelsize=13)
    plt.xticks(rotation=45)
    sns.despine()
    plt.subplots_adjust(wspace=0.5)
    plt.show(block=False)
