# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB_diversity.csv")

# %%
# Calculate clonality
df['clonality_TCR'] = 1 - (df['shannon_index_TCR']/np.log(df['clonotype_count_TCR']))
df['clonality_tool'] = 1 - (df['shannon_index_tool']/np.log(df['clonotype_count_tool']))
df['clonality_absolute_error'] = np.abs(df['clonality_TCR'] - df['clonality_tool'])
df
# Out:
#           Sample  shannon_index_tool  clonotype_count_tool    tool  \
# 0     SRR5233637            3.061608                    24   MIXCR
# 1     SRR5233637            4.562193                   115   IMREP
# 2     SRR5233637            4.309543                   118  TRUST4
# 3     SRR5233639            5.478183                   353   MIXCR
# 4     SRR5233639            7.548679                  2342   IMREP
# 5     SRR5233639            7.186224                  2362  TRUST4
# 6       sample01            0.829164                  2592   MIXCR
# 7       sample01            1.163479                  3682   IMREP
# 8       sample01            1.165598                  4154  TRUST4
# 9       sample02            0.988740                  1565   MIXCR
# 10      sample02            2.440028                  4392   IMREP
# 11      sample02            2.222923                  5275  TRUST4
# 12      sample03            0.792264                  1012   MIXCR
# 13      sample03            1.875318                  3513   IMREP
# 14      sample03            1.607361                  3923  TRUST4
# 15      sample04            3.963013                    62   MIXCR
# 16      sample04            6.152715                   522   IMREP
# 17      sample04            6.298032                   701  TRUST4
# 18      sample05            2.894962                    20   MIXCR
# 19      sample05            3.282380                    33   IMREP
# 20      sample05            3.707384                    50  TRUST4
# 21      sample06            3.438804                    34   MIXCR
# 22      sample06            4.406335                    92   IMREP
# 23      sample06            5.024401                   200  TRUST4
# 24      sample08            3.438274                    39   MIXCR
# 25      sample08            3.757841                    57   IMREP
# 26      sample08            3.956740                    88  TRUST4
# 27      sample09            3.013201                    44   MIXCR
# 28      sample09            3.793673                    80   IMREP
# 29      sample09            3.919626                   130  TRUST4
# 30      sample10            2.394503                    17   MIXCR
# 31      sample10            3.176253                    28   IMREP
# 32      sample10            3.402329                    58  TRUST4
# 33      sample11            1.589027                     5   MIXCR
# 34      sample11            2.346659                    11   IMREP
# 35      sample11            2.215597                    13  TRUST4
# 36      sample12            1.386294                     4   MIXCR
# 37      sample12            1.332179                     4   IMREP
# 38      sample12            2.228305                    11  TRUST4
# 39      sample13            3.744250                    96   MIXCR
# 40      sample13            4.163526                   116   IMREP
# 41      sample13            4.055173                   175  TRUST4
# 42      sample14            3.319145                    32   MIXCR
# 43      sample14            3.503699                    41   IMREP
# 44      sample14            3.899303                    66  TRUST4
# 45  TCGA-CZ-4862            2.593166                    16   IMREP
# 46  TCGA-CZ-4862            3.295876                    67  TRUST4
# 47  TCGA-CZ-5463            1.305096                     4   IMREP
# 48  TCGA-CZ-5463            2.570407                    24  TRUST4
# 49  TCGA-CZ-5985            0.462037                     2   IMREP
# 50  TCGA-CZ-5985            2.174110                    22  TRUST4
# 51      sample07            0.000000                     1   IMREP
# 52      sample07            0.970585                     4  TRUST4
#
#     shannon_index_TCR  clonotype_count_TCR repertoire_type           tissue  \
# 0            7.712411                27947      polyclonal  small_intestine
# 1            7.712411                27947      polyclonal  small_intestine
# 2            7.712411                27947      polyclonal  small_intestine
# 3           10.059157               202869      polyclonal       lymph_node
# 4           10.059157               202869      polyclonal       lymph_node
# 5           10.059157               202869      polyclonal       lymph_node
# 6            1.072675                 3001      monoclonal             PBMC
# 7            1.072675                 3001      monoclonal             PBMC
# 8            1.072675                 3001      monoclonal             PBMC
# 9            1.001202                 3229      monoclonal             PBMC
# 10           1.001202                 3229      monoclonal             PBMC
# 11           1.001202                 3229      monoclonal             PBMC
# 12           0.960516                 7697      monoclonal             PBMC
# 13           0.960516                 7697      monoclonal             PBMC
# 14           0.960516                 7697      monoclonal             PBMC
# 15           9.598323                26802      polyclonal             PBMC
# 16           9.598323                26802      polyclonal             PBMC
# 17           9.598323                26802      polyclonal             PBMC
# 18           8.005115                 5440      polyclonal             PBMC
# 19           8.005115                 5440      polyclonal             PBMC
# 20           8.005115                 5440      polyclonal             PBMC
# 21           8.172351                 9354      polyclonal         melanoma
# 22           8.172351                 9354      polyclonal         melanoma
# 23           8.172351                 9354      polyclonal         melanoma
# 24           8.035551                12844      polyclonal         melanoma
# 25           8.035551                12844      polyclonal         melanoma
# 26           8.035551                12844      polyclonal         melanoma
# 27           7.651713                19018      polyclonal         melanoma
# 28           7.651713                19018      polyclonal         melanoma
# 29           7.651713                19018      polyclonal         melanoma
# 30           7.207395                16417      polyclonal         melanoma
# 31           7.207395                16417      polyclonal         melanoma
# 32           7.207395                16417      polyclonal         melanoma
# 33           7.730309                 6178      polyclonal         melanoma
# 34           7.730309                 6178      polyclonal         melanoma
# 35           7.730309                 6178      polyclonal         melanoma
# 36           6.546400                 3817      polyclonal         melanoma
# 37           6.546400                 3817      polyclonal         melanoma
# 38           6.546400                 3817      polyclonal         melanoma
# 39           1.520791                   53      monoclonal         melanoma
# 40           1.520791                   53      monoclonal         melanoma
# 41           1.520791                   53      monoclonal         melanoma
# 42           6.941821                 4557      polyclonal         melanoma
# 43           6.941821                 4557      polyclonal         melanoma
# 44           6.941821                 4557      polyclonal         melanoma
# 45           7.485462                 4237      polyclonal           kidney
# 46           7.485462                 4237      polyclonal           kidney
# 47           2.957966                   99      polyclonal           kidney
# 48           2.957966                   99      polyclonal           kidney
# 49           5.638249                 1415      polyclonal           kidney
# 50           5.638249                 1415      polyclonal           kidney
# 51           4.680209                 3548      polyclonal         melanoma
# 52           4.680209                 3548      polyclonal         melanoma
#
#     tissue_type  absolute_error                   class  clonality_TCR  \
# 0   T_cell_poor        4.650803  T_cell_poor_polyclonal       0.246692
# 1   T_cell_poor        3.150218  T_cell_poor_polyclonal       0.246692
# 2   T_cell_poor        3.402869  T_cell_poor_polyclonal       0.246692
# 3   T_cell_rich        4.580975  T_cell_rich_polyclonal       0.176850
# 4   T_cell_rich        2.510478  T_cell_rich_polyclonal       0.176850
# 5   T_cell_rich        2.872934  T_cell_rich_polyclonal       0.176850
# 6   T_cell_rich        0.243510  T_cell_rich_monoclonal       0.866028
# 7   T_cell_rich        0.090805  T_cell_rich_monoclonal       0.866028
# 8   T_cell_rich        0.092923  T_cell_rich_monoclonal       0.866028
# 9   T_cell_rich        0.012462  T_cell_rich_monoclonal       0.876088
# 10  T_cell_rich        1.438827  T_cell_rich_monoclonal       0.876088
# 11  T_cell_rich        1.221721  T_cell_rich_monoclonal       0.876088
# 12  T_cell_rich        0.168253  T_cell_rich_monoclonal       0.892663
# 13  T_cell_rich        0.914802  T_cell_rich_monoclonal       0.892663
# 14  T_cell_rich        0.646845  T_cell_rich_monoclonal       0.892663
# 15  T_cell_rich        5.635310  T_cell_rich_polyclonal       0.058640
# 16  T_cell_rich        3.445608  T_cell_rich_polyclonal       0.058640
# 17  T_cell_rich        3.300291  T_cell_rich_polyclonal       0.058640
# 18  T_cell_rich        5.110153  T_cell_rich_polyclonal       0.069339
# 19  T_cell_rich        4.722735  T_cell_rich_polyclonal       0.069339
# 20  T_cell_rich        4.297731  T_cell_rich_polyclonal       0.069339
# 21  T_cell_poor        4.733547  T_cell_poor_polyclonal       0.106218
# 22  T_cell_poor        3.766016  T_cell_poor_polyclonal       0.106218
# 23  T_cell_poor        3.147950  T_cell_poor_polyclonal       0.106218
# 24  T_cell_poor        4.597277  T_cell_poor_polyclonal       0.150633
# 25  T_cell_poor        4.277710  T_cell_poor_polyclonal       0.150633
# 26  T_cell_poor        4.078811  T_cell_poor_polyclonal       0.150633
# 27  T_cell_poor        4.638512  T_cell_poor_polyclonal       0.223424
# 28  T_cell_poor        3.858040  T_cell_poor_polyclonal       0.223424
# 29  T_cell_poor        3.732087  T_cell_poor_polyclonal       0.223424
# 30  T_cell_poor        4.812892  T_cell_poor_polyclonal       0.257435
# 31  T_cell_poor        4.031142  T_cell_poor_polyclonal       0.257435
# 32  T_cell_poor        3.805066  T_cell_poor_polyclonal       0.257435
# 33  T_cell_poor        6.141282  T_cell_poor_polyclonal       0.114385
# 34  T_cell_poor        5.383650  T_cell_poor_polyclonal       0.114385
# 35  T_cell_poor        5.514711  T_cell_poor_polyclonal       0.114385
# 36  T_cell_poor        5.160106  T_cell_poor_polyclonal       0.206230
# 37  T_cell_poor        5.214221  T_cell_poor_polyclonal       0.206230
# 38  T_cell_poor        4.318095  T_cell_poor_polyclonal       0.206230
# 39  T_cell_poor        2.223459  T_cell_poor_monoclonal       0.616957
# 40  T_cell_poor        2.642735  T_cell_poor_monoclonal       0.616957
# 41  T_cell_poor        2.534382  T_cell_poor_monoclonal       0.616957
# 42  T_cell_poor        3.622676  T_cell_poor_polyclonal       0.175988
# 43  T_cell_poor        3.438123  T_cell_poor_polyclonal       0.175988
# 44  T_cell_poor        3.042519  T_cell_poor_polyclonal       0.175988
# 45  T_cell_poor        4.892296  T_cell_poor_polyclonal       0.103710
# 46  T_cell_poor        4.189586  T_cell_poor_polyclonal       0.103710
# 47  T_cell_poor        1.652870  T_cell_poor_polyclonal       0.356281
# 48  T_cell_poor        0.387559  T_cell_poor_polyclonal       0.356281
# 49  T_cell_poor        5.176212  T_cell_poor_polyclonal       0.222834
# 50  T_cell_poor        3.464139  T_cell_poor_polyclonal       0.222834
# 51  T_cell_poor        4.680209  T_cell_poor_polyclonal       0.427437
# 52  T_cell_poor        3.709624  T_cell_poor_polyclonal       0.427437
#
#     clonality_tool  clonality_absolute_error
# 0         0.036640                  0.210052
# 1         0.038512                  0.208180
# 2         0.096662                  0.150031
# 3         0.066187                  0.110662
# 4         0.027077                  0.149773
# 5         0.074806                  0.102043
# 6         0.894511                  0.028483
# 7         0.858306                  0.007722
# 8         0.860103                  0.005925
# 9         0.865581                  0.010507
# 10        0.709089                  0.166999
# 11        0.740638                  0.135450
# 12        0.885506                  0.007157
# 13        0.770301                  0.122362
# 14        0.805748                  0.086915
# 15        0.039767                  0.018874
# 16        0.016772                  0.041868
# 17        0.038836                  0.019804
# 18        0.033638                  0.035701
# 19        0.061240                  0.008098
# 20        0.052310                  0.017028
# 21        0.024829                  0.081389
# 22        0.025533                  0.080685
# 23        0.051699                  0.054519
# 24        0.061494                  0.089139
# 25        0.070543                  0.080089
# 26        0.116274                  0.034359
# 27        0.203739                  0.019685
# 28        0.134265                  0.089159
# 29        0.194741                  0.028683
# 30        0.154845                  0.102589
# 31        0.046801                  0.210633
# 32        0.162079                  0.095355
# 33        0.012682                  0.101703
# 34        0.021367                  0.093018
# 35        0.136202                  0.021817
# 36        0.000000                  0.206230
# 37        0.039036                  0.167194
# 38        0.070725                  0.135505
# 39        0.179675                  0.437283
# 40        0.124130                  0.492827
# 41        0.214842                  0.402115
# 42        0.042297                  0.133691
# 43        0.056515                  0.119473
# 44        0.069302                  0.106686
# 45        0.064713                  0.038997
# 46        0.216143                  0.112433
# 47        0.058572                  0.297709
# 48        0.191201                  0.165080
# 49        0.333422                  0.110588
# 50        0.296642                  0.073808
# 51             NaN                       NaN
# 52        0.299871                  0.127566

# %% [markdown]
# ## Figure 2a

# %% [markdown]
# SDI comparison in T cell rich tissues

# %%
T_cell_rich = df.loc[(df['tissue_type'] == 'T_cell_rich')]

# %%
# MIXCR
T_cell_rich_MIXCR = T_cell_rich.loc[(T_cell_rich['tool'] == 'MIXCR')]
f, ax = plt.subplots(figsize=(5, 5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='shannon_index_TCR', y='shannon_index_tool', hue='repertoire_type', 
                    hue_order = ['monoclonal','polyclonal'], s=100, data=T_cell_rich_MIXCR, palette=['#4878d0', '#ee854a'])

g = sns.lineplot(x=range(0,12),y=range(0,12),color=".7")
g.lines[0].set_linestyle("--")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[1:], labels[1:], loc='upper right', bbox_to_anchor=(0.5, 1), frameon=False)
    
g.axes.set_title('MIXCR',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based SDI",fontsize=15)
g.set_ylabel("RNA-Seq-based SDI",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()
 
r, p = stats.pearsonr(T_cell_rich_MIXCR['shannon_index_TCR'], T_cell_rich_MIXCR['shannon_index_tool'])
plt.text(6,0.5,'r={:.2f}, p={:.2g}'.format(r, p),fontsize=15)
    
fig = ax.get_figure()

fig.savefig("../figures/main/figure2_a1.pdf",bbox_inches="tight")
fig.savefig("../figures/main/figure2_a1.png",bbox_inches="tight")

# %%
# IMREP
T_cell_rich_IMREP = T_cell_rich.loc[(T_cell_rich['tool'] == 'IMREP')]
f, ax = plt.subplots(figsize=(5, 5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='shannon_index_TCR', y='shannon_index_tool', hue='repertoire_type', 
                     hue_order = ['monoclonal','polyclonal'], s=100, data=T_cell_rich_IMREP, palette=['#4878d0', '#ee854a'])
g = sns.lineplot(x=range(0,12),y=range(0,12),color=".7")
g.lines[0].set_linestyle("--")
    
handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[1:], labels[1:], loc='upper right', bbox_to_anchor=(0.5, 1), frameon=False)

g.axes.set_title('IMREP',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based SDI",fontsize=15)
g.set_ylabel("RNA-Seq-based SDI",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()
 
r, p = stats.pearsonr(T_cell_rich_IMREP['shannon_index_TCR'], T_cell_rich_IMREP['shannon_index_tool'])
plt.text(6,0.5,'r={:.2f}, p={:.2g}'.format(r, p),fontsize=15)
    
fig = ax.get_figure()

fig.savefig("../figures/main/figure2_a2.pdf",bbox_inches="tight")
fig.savefig("../figures/main/figure2_a2.png",bbox_inches="tight")

# %%
# TRUST4
T_cell_rich_TRUST4 = T_cell_rich.loc[(T_cell_rich['tool'] == 'TRUST4')]
f, ax = plt.subplots(figsize=(5, 5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='shannon_index_TCR', y='shannon_index_tool', hue='repertoire_type',
                    hue_order = ['monoclonal','polyclonal'], s=100, data=T_cell_rich_TRUST4, palette=['#4878d0', '#ee854a'])
g = sns.lineplot(x=range(0,12),y=range(0,12),color=".7")
g.lines[0].set_linestyle("--")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[1:], labels[1:], loc='upper right', bbox_to_anchor=(0.5, 1), frameon=False)
    
g.axes.set_title('TRUST4',fontsize=15,y=1.05)
g.set_xlabel("TCR-Seq-based SDI",fontsize=15)
g.set_ylabel("RNA-Seq-based SDI",fontsize=15)

plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()
 
r, p = stats.pearsonr(T_cell_rich_TRUST4['shannon_index_TCR'], T_cell_rich_TRUST4['shannon_index_tool'])
plt.text(6,0.5,'r={:.2f}, p={:.2g}'.format(r, p),fontsize=15)
    
fig = ax.get_figure()

fig.savefig("../figures/main/figure2_a3.pdf",bbox_inches="tight")
fig.savefig("../figures/main/figure2_a3.png",bbox_inches="tight")

# %% [markdown]
# Absolute error of SDI in T cell rich tissues

# %%
mean_absolute_error = T_cell_rich['absolute_error'].mean()
print("Mean")
display(mean_absolute_error)

mean_absolute_error_std = T_cell_rich['absolute_error'].std()
print("STD")
display(mean_absolute_error_std)

mean_absolute_error_tool = T_cell_rich.groupby("tool")["absolute_error"].agg(["mean", "std"])
display(mean_absolute_error_tool)
# Out:
# Mean
# 2.2947979150057174
# STD
# 1.9864808747899814
#             mean       std
# tool
# IMREP   2.187209  1.714116
# MIXCR   2.625110  2.742125
# TRUST4  2.072074  1.659811

# %% [markdown]
# ## Figure S7a

# %% [markdown]
# SDI comparison in T poor polyclonal repertoires

# %%
T_cell_poor = df.loc[(df['tissue_type'] == 'T_cell_poor')]

# %%
# MIXCR
T_cell_poor_MIXCR = T_cell_poor.loc[(T_cell_poor['tool'] == 'MIXCR')]
f, ax = plt.subplots(figsize=(5, 5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='shannon_index_TCR', y='shannon_index_tool', hue='repertoire_type', s=50, 
                    hue_order=['monoclonal','polyclonal'], data=T_cell_poor_MIXCR, palette=['#6acc64','#d65f5f'])
g = sns.lineplot(x=range(0,12),y=range(0,12),color=".7")
g.lines[0].set_linestyle("--")
    
handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[1:], labels[1:], loc='upper right', bbox_to_anchor=(0.5, 1), frameon=False)

g.axes.set_title('MIXCR',fontsize=20,y=1.05)
g.set_xlabel("TCR-Seq-based SDI",fontsize=15)
g.set_ylabel("RNA-Seq-based SDI",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
sns.despine()
 
r, p = stats.pearsonr(T_cell_poor_MIXCR['shannon_index_TCR'], T_cell_poor_MIXCR['shannon_index_tool'])
plt.text(6,0.5,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)

fig = ax.get_figure()

fig.savefig("../figures/supplementary/figureS7_a1.pdf",bbox_inches="tight")
fig.savefig("../figures/supplementary/figureS7_a1.png",bbox_inches="tight")

# %%
# IMREP
T_cell_poor_IMREP = T_cell_poor.loc[(T_cell_poor['tool'] == 'IMREP')]
f, ax = plt.subplots(figsize=(5, 5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='shannon_index_TCR', y='shannon_index_tool', hue='repertoire_type', s=50, 
                    hue_order=['monoclonal','polyclonal'], data=T_cell_poor_IMREP, palette=['#6acc64','#d65f5f'])
g = sns.lineplot(x=range(0,12),y=range(0,12),color=".7")
g.lines[0].set_linestyle("--")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[1:], labels[1:], loc='upper right', bbox_to_anchor=(0.5, 1), frameon=False)
    
g.axes.set_title('IMREP',fontsize=20,y=1.05)
g.set_xlabel("TCR-Seq-based SDI",fontsize=15)
g.set_ylabel("RNA-Seq-based SDI",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
sns.despine()
 
r, p = stats.pearsonr(T_cell_poor_IMREP['shannon_index_TCR'], T_cell_poor_IMREP['shannon_index_tool'])
plt.text(6,0.5,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)

fig = ax.get_figure()

fig.savefig("../figures/supplementary/figureS7_a2.pdf",bbox_inches="tight")
fig.savefig("../figures/supplementary/figureS7_a2.png",bbox_inches="tight")

# %%
# TRUST4
T_cell_poor_TRUST4 = T_cell_poor.loc[(T_cell_poor['tool'] == 'TRUST4')]
f, ax = plt.subplots(figsize=(5, 5))
g = sns.set_style("white") 
g = sns.set_context("talk") 
g = sns.scatterplot(x='shannon_index_TCR', y='shannon_index_tool', hue='repertoire_type', s=50, 
                     hue_order=['monoclonal','polyclonal'], data=T_cell_poor_TRUST4,palette=['#6acc64','#d65f5f'])
g = sns.lineplot(x=range(0,12),y=range(0,12),color=".7")
g.lines[0].set_linestyle("--")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[1:], labels[1:], loc='upper right', bbox_to_anchor=(0.5, 1), frameon=False)
    
g.axes.set_title('TRUST4',fontsize=20,y=1.05)
g.set_xlabel("TCR-Seq-based SDI",fontsize=15)
g.set_ylabel("RNA-Seq-based SDI",fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
sns.despine()
 
r, p = stats.pearsonr(T_cell_poor_TRUST4['shannon_index_TCR'], T_cell_poor_TRUST4['shannon_index_tool'])
plt.text(6,0.5,'r={:.4f}, p={:.2g}'.format(r, p),fontsize=15)

fig = ax.get_figure()

fig.savefig("../figures/supplementary/figureS7_a3.pdf",bbox_inches="tight")
fig.savefig("../figures/supplementary/figureS7_a3.png",bbox_inches="tight")

# %% [markdown]
# ## Figure 2b

# %%
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (10,10))
fig = df.loc[(df['class'] != 'T_cell_poor_polyclonal')]
ax = sns.barplot(x='class',y='absolute_error',data=fig,palette="muted",hue='tool',alpha=0.7,
                order=['T_cell_rich_monoclonal','T_cell_rich_polyclonal','T_cell_poor_monoclonal'])
sns.stripplot(x="class",y="absolute_error",data=fig,s=10,color=".3",palette="muted",hue='tool',dodge=True,
              linewidth=1,order=['T_cell_rich_monoclonal','T_cell_rich_polyclonal','T_cell_poor_monoclonal'])

ax.set_xlabel('Sample type',fontsize=20)
ax.set_ylabel('Absolute error of SDI',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(rotation=45)
handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1), frameon=False)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()
plt.show()

fig = ax.get_figure()

fig.savefig("../figures/main/figure2_b.pdf",bbox_inches="tight")
fig.savefig("../figures/main/figure2_b.png",bbox_inches="tight")

# %% [markdown]
# Absolute error of SDI in different classes of repertoires

# %%
mean_repertoire_absolute_error = df.groupby("class")["absolute_error"].agg(["mean", "std"])
display(mean_repertoire_absolute_error)
tools = ['MIXCR','IMREP','TRUST4']              
for tool in tools:  
    print(tool)
    df_tool = df.loc[df['tool'] == tool]
    mean_repertoire_absolute_error = df_tool.groupby("class")["absolute_error"].agg(["mean", "std"]) 
    display(mean_repertoire_absolute_error)
# Out:
#                             mean       std
# class
# T_cell_poor_monoclonal  2.466859  0.217641
# T_cell_poor_polyclonal  4.083463  1.120718
# T_cell_rich_monoclonal  0.536683  0.539731
# T_cell_rich_polyclonal  4.052913  1.067468
# MIXCR
#                             mean       std
# class
# T_cell_poor_monoclonal  2.223459       NaN
# T_cell_poor_polyclonal  4.794637  0.697812
# T_cell_rich_monoclonal  0.141408  0.117840
# T_cell_rich_polyclonal  5.108813  0.527169
# IMREP
#                             mean       std
# class
# T_cell_poor_monoclonal  2.642735       NaN
# T_cell_poor_polyclonal  4.126726  1.067636
# T_cell_rich_monoclonal  0.814811  0.679551
# T_cell_rich_polyclonal  3.559607  1.110525
# TRUST4
#                             mean       std
# class
# T_cell_poor_monoclonal  2.534382       NaN
# T_cell_poor_polyclonal  3.566085  1.195012
# T_cell_rich_monoclonal  0.653830  0.564431
# T_cell_rich_polyclonal  3.490319  0.731160

# %% [markdown]
# ## Figure S3

# %% [markdown]
# Absolute error of SDI in different tissue types among polyclonal repertoires

# %%
polyclonal_repertoires = df.loc[(df['repertoire_type'] == 'polyclonal')]

# %%
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (10,10))
ax = sns.barplot(x='tissue',y='absolute_error',data=polyclonal_repertoires,palette="muted",hue='tool',
                order=['PBMC','lymph_node','melanoma','small_intestine','kidney'],alpha=0.7)
sns.stripplot(x="tissue",y="absolute_error",data=polyclonal_repertoires,s=8,color=".3",palette="muted",hue='tool',
              dodge=True,linewidth=1,order=['PBMC','lymph_node','melanoma','small_intestine','kidney'])

ax.set_xlabel('Tissue type',fontsize=20)
ax.set_ylabel('Absolute error of SDI',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(rotation=45)
handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1), frameon=False)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()
plt.show()

fig = ax.get_figure()

fig.savefig("../figures/supplementary/figureS3_a.pdf",bbox_inches="tight")
fig.savefig("../figures/supplementary/figureS3_a.png",bbox_inches="tight")

# %%
mean_tissue_absolute_error = polyclonal_repertoires.groupby("tissue")["absolute_error"].agg(["mean", "std"]) 
display(mean_tissue_absolute_error)
tools = ['MIXCR','IMREP','TRUST4']              
for tool in tools: 
    print(tool)
    df_tool = polyclonal_repertoires.loc[polyclonal_repertoires['tool'] == tool]
    mean_tissue_absolute_error = df_tool.groupby("tissue")["absolute_error"].agg(["mean", "std"]) 
    display(mean_tissue_absolute_error)
# Out:
#                      mean       std
# tissue
# PBMC             4.418638  0.923370
# kidney           3.293777  1.901000
# lymph_node       3.321462  1.105723
# melanoma         4.334968  0.798144
# small_intestine  3.734630  0.803423
# MIXCR
#                      mean       std
# tissue
# PBMC             5.372732  0.371342
# lymph_node       4.580975       NaN
# melanoma         4.815184  0.751104
# small_intestine  4.650803       NaN
# IMREP
#                      mean       std
# tissue
# PBMC             4.084172  0.903065
# kidney           3.907126  1.957398
# lymph_node       2.510478       NaN
# melanoma         4.331139  0.701323
# small_intestine  3.150218       NaN
# TRUST4
#                      mean       std
# tissue
# PBMC             3.799011  0.705297
# kidney           2.680428  2.018540
# lymph_node       2.872934       NaN
# melanoma         3.918608  0.773268
# small_intestine  3.402869       NaN

# %% [markdown]
# Absolute error of clonality in T cell rich tissues

# %%
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (10,10))
ax = sns.barplot(x='class',y='clonality_absolute_error',data=T_cell_rich,palette="muted",hue='tool',
                 alpha=0.7,order=['T_cell_rich_monoclonal','T_cell_rich_polyclonal'])
sns.stripplot(x="class",y="clonality_absolute_error",data=T_cell_rich,s=10,color=".3",palette="muted",hue='tool',dodge=True,
              linewidth=1,order=['T_cell_rich_monoclonal','T_cell_rich_polyclonal'])

ax.set_xlabel('Sample type',fontsize=20)
ax.set_ylabel('Absolute error of clonality',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(rotation=45)
handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1), frameon=False)
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
sns.despine()
plt.show()

fig = ax.get_figure()

fig.savefig("../figures/supplementary/figureS3_b.pdf",bbox_inches="tight")
fig.savefig("../figures/supplementary/figureS3_b.png",bbox_inches="tight")

# %%
mean_repertoire_absolute_error = T_cell_rich.groupby("class")["clonality_absolute_error"].agg(["mean", "std"])
display(mean_repertoire_absolute_error)
tools = ['MIXCR','IMREP','TRUST4']              
for tool in tools:
    print(tool)
    df_tool = T_cell_rich.loc[df['tool'] == tool]
    mean_clonotype_tool = df_tool.groupby("class")["clonality_absolute_error"].agg(["mean", "std"]) 
    display(mean_clonotype_tool)
# Out:
#                             mean       std
# class
# T_cell_rich_monoclonal  0.063502  0.064747
# T_cell_rich_polyclonal  0.055984  0.051253
# MIXCR
#                             mean       std
# class
# T_cell_rich_monoclonal  0.015382  0.011468
# T_cell_rich_polyclonal  0.055079  0.048866
# IMREP
#                             mean       std
# class
# T_cell_rich_monoclonal  0.099028  0.082162
# T_cell_rich_polyclonal  0.066580  0.073999
# TRUST4
#                             mean       std
# class
# T_cell_rich_monoclonal  0.076097  0.065437
# T_cell_rich_polyclonal  0.046292  0.048302
