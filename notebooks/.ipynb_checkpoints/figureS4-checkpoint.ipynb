# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB_reads.csv")
df
# Out:
#           Sample           tissue  tissue_type repertoire_type  \
# 0     SRR5233637  small_intestine  T_cell_poor      polyclonal
# 1     SRR5233639       lymph_node  T_cell_rich      polyclonal
# 2   TCGA-CZ-4862           kidney  T_cell_poor      polyclonal
# 3   TCGA-CZ-5463           kidney  T_cell_poor      polyclonal
# 4   TCGA-CZ-5985           kidney  T_cell_poor      polyclonal
# 5       sample01             PBMC  T_cell_rich      monoclonal
# 6       sample02             PBMC  T_cell_rich      monoclonal
# 7       sample03             PBMC  T_cell_rich      monoclonal
# 8       sample04             PBMC  T_cell_rich      polyclonal
# 9       sample05             PBMC  T_cell_rich      polyclonal
# 10      sample06         melanoma  T_cell_poor      polyclonal
# 11      sample07         melanoma  T_cell_poor      polyclonal
# 12      sample08         melanoma  T_cell_poor      polyclonal
# 13      sample09         melanoma  T_cell_poor      polyclonal
# 14      sample10         melanoma  T_cell_poor      polyclonal
# 15      sample11         melanoma  T_cell_poor      polyclonal
# 16      sample12         melanoma  T_cell_poor      polyclonal
# 17      sample13         melanoma  T_cell_poor      monoclonal
# 18      sample14         melanoma  T_cell_poor      polyclonal
# 19    SRR5233637  small_intestine  T_cell_poor      polyclonal
# 20    SRR5233639       lymph_node  T_cell_rich      polyclonal
# 21  TCGA-CZ-4862           kidney  T_cell_poor      polyclonal
# 22  TCGA-CZ-5463           kidney  T_cell_poor      polyclonal
# 23  TCGA-CZ-5985           kidney  T_cell_poor      polyclonal
# 24      sample01             PBMC  T_cell_rich      monoclonal
# 25      sample02             PBMC  T_cell_rich      monoclonal
# 26      sample03             PBMC  T_cell_rich      monoclonal
# 27      sample04             PBMC  T_cell_rich      polyclonal
# 28      sample05             PBMC  T_cell_rich      polyclonal
# 29      sample06         melanoma  T_cell_poor      polyclonal
# 30      sample07         melanoma  T_cell_poor      polyclonal
# 31      sample08         melanoma  T_cell_poor      polyclonal
# 32      sample09         melanoma  T_cell_poor      polyclonal
# 33      sample10         melanoma  T_cell_poor      polyclonal
# 34      sample11         melanoma  T_cell_poor      polyclonal
# 35      sample12         melanoma  T_cell_poor      polyclonal
# 36      sample13         melanoma  T_cell_poor      monoclonal
# 37      sample14         melanoma  T_cell_poor      polyclonal
# 38    SRR5233637  small_intestine  T_cell_poor      polyclonal
# 39    SRR5233639       lymph_node  T_cell_rich      polyclonal
# 40  TCGA-CZ-4862           kidney  T_cell_poor      polyclonal
# 41  TCGA-CZ-5463           kidney  T_cell_poor      polyclonal
# 42  TCGA-CZ-5985           kidney  T_cell_poor      polyclonal
# 43      sample01             PBMC  T_cell_rich      monoclonal
# 44      sample02             PBMC  T_cell_rich      monoclonal
# 45      sample03             PBMC  T_cell_rich      monoclonal
# 46      sample04             PBMC  T_cell_rich      polyclonal
# 47      sample05             PBMC  T_cell_rich      polyclonal
# 48      sample06         melanoma  T_cell_poor      polyclonal
# 49      sample07         melanoma  T_cell_poor      polyclonal
# 50      sample08         melanoma  T_cell_poor      polyclonal
# 51      sample09         melanoma  T_cell_poor      polyclonal
# 52      sample10         melanoma  T_cell_poor      polyclonal
# 53      sample11         melanoma  T_cell_poor      polyclonal
# 54      sample12         melanoma  T_cell_poor      polyclonal
# 55      sample13         melanoma  T_cell_poor      monoclonal
# 56      sample14         melanoma  T_cell_poor      polyclonal
#
#                      class  total_reads_TCR  total_reads_tool  \
# 0   T_cell_poor_polyclonal        3047629.0              84.0
# 1   T_cell_rich_polyclonal        3256697.0            1346.0
# 2   T_cell_poor_polyclonal          16784.0               0.0
# 3   T_cell_poor_polyclonal            806.0               0.0
# 4   T_cell_poor_polyclonal          12998.0               0.0
# 5   T_cell_rich_monoclonal          90577.0          132472.0
# 6   T_cell_rich_monoclonal          87762.0           41370.0
# 7   T_cell_rich_monoclonal         305953.0           52066.0
# 8   T_cell_rich_polyclonal         104779.0             158.0
# 9   T_cell_rich_polyclonal          18617.0              55.0
# 10  T_cell_poor_polyclonal         906121.0              91.0
# 11  T_cell_poor_polyclonal        1257571.0               0.0
# 12  T_cell_poor_polyclonal        1408590.0             150.0
# 13  T_cell_poor_polyclonal        1157845.0             310.0
# 14  T_cell_poor_polyclonal        1769522.0              59.0
# 15  T_cell_poor_polyclonal        1006220.0              12.0
# 16  T_cell_poor_polyclonal         292828.0               8.0
# 17  T_cell_poor_monoclonal          12954.0            1071.0
# 18  T_cell_poor_polyclonal         749686.0             113.0
# 19  T_cell_poor_polyclonal        3047629.0             315.0
# 20  T_cell_rich_polyclonal        3256697.0            6143.0
# 21  T_cell_poor_polyclonal          16784.0              50.0
# 22  T_cell_poor_polyclonal            806.0              16.0
# 23  T_cell_poor_polyclonal          12998.0              23.0
# 24  T_cell_rich_monoclonal          90577.0          219185.0
# 25  T_cell_rich_monoclonal          87762.0           57700.0
# 26  T_cell_rich_monoclonal         305953.0           64914.0
# 27  T_cell_rich_polyclonal         104779.0            1354.0
# 28  T_cell_rich_polyclonal          18617.0             111.0
# 29  T_cell_poor_polyclonal         906121.0             231.0
# 30  T_cell_poor_polyclonal        1257571.0               2.0
# 31  T_cell_poor_polyclonal        1408590.0             259.0
# 32  T_cell_poor_polyclonal        1157845.0             334.0
# 33  T_cell_poor_polyclonal        1769522.0              71.0
# 34  T_cell_poor_polyclonal        1006220.0              31.0
# 35  T_cell_poor_polyclonal         292828.0              10.0
# 36  T_cell_poor_monoclonal          12954.0             844.0
# 37  T_cell_poor_polyclonal         749686.0             152.0
# 38  T_cell_poor_polyclonal        3047629.0             544.0
# 39  T_cell_rich_polyclonal        3256697.0            9054.0
# 40  T_cell_poor_polyclonal          16784.0             710.0
# 41  T_cell_poor_polyclonal            806.0             366.0
# 42  T_cell_poor_polyclonal          12998.0             282.0
# 43  T_cell_rich_monoclonal          90577.0          264884.0
# 44  T_cell_rich_monoclonal          87762.0           89947.0
# 45  T_cell_rich_monoclonal         305953.0           99723.0
# 46  T_cell_rich_polyclonal         104779.0            2006.0
# 47  T_cell_rich_polyclonal          18617.0             186.0
# 48  T_cell_poor_polyclonal         906121.0             689.0
# 49  T_cell_poor_polyclonal        1257571.0              19.0
# 50  T_cell_poor_polyclonal        1408590.0             657.0
# 51  T_cell_poor_polyclonal        1157845.0            1009.0
# 52  T_cell_poor_polyclonal        1769522.0             306.0
# 53  T_cell_poor_polyclonal        1006220.0              63.0
# 54  T_cell_poor_polyclonal         292828.0              39.0
# 55  T_cell_poor_monoclonal          12954.0            2855.0
# 56  T_cell_poor_polyclonal         749686.0             351.0
#
#     total_reads_RNA_seq    tool  TCR_derived_by_RNA_seq_tool
# 0              72720367   MIXCR                     1.155110
# 1              65998918   MIXCR                    20.394274
# 2              58529923   MIXCR                     0.000000
# 3             122632451   MIXCR                     0.000000
# 4              83862519   MIXCR                     0.000000
# 5             104984482   MIXCR                  1261.824581
# 6              73892845   MIXCR                   559.864761
# 7              71654976   MIXCR                   726.620856
# 8              43179989   MIXCR                     3.659102
# 9              40524817   MIXCR                     1.357193
# 10             82476159   MIXCR                     1.103349
# 11             72397468   MIXCR                     0.000000
# 12             85492431   MIXCR                     1.754541
# 13             68584414   MIXCR                     4.519977
# 14             63320771   MIXCR                     0.931764
# 15             55727841   MIXCR                     0.215332
# 16            107919183   MIXCR                     0.074130
# 17             80622502   MIXCR                    13.284133
# 18             55931661   MIXCR                     2.020323
# 19             72720367   IMREP                     4.331661
# 20             65998918   IMREP                    93.077283
# 21             58529923   IMREP                     0.854264
# 22            122632451   IMREP                     0.130471
# 23             83862519   IMREP                     0.274258
# 24            104984482   IMREP                  2087.784745
# 25             73892845   IMREP                   780.860447
# 26             71654976   IMREP                   905.924524
# 27             43179989   IMREP                    31.357118
# 28             40524817   IMREP                     2.739062
# 29             82476159   IMREP                     2.800809
# 30             72397468   IMREP                     0.027625
# 31             85492431   IMREP                     3.029508
# 32             68584414   IMREP                     4.869911
# 33             63320771   IMREP                     1.121275
# 34             55727841   IMREP                     0.556275
# 35            107919183   IMREP                     0.092662
# 36             80622502   IMREP                    10.468541
# 37             55931661   IMREP                     2.717602
# 38             72720367  TRUST4                     7.480710
# 39             65998918  TRUST4                   137.184067
# 40             58529923  TRUST4                    12.130547
# 41            122632451  TRUST4                     2.984528
# 42             83862519  TRUST4                     3.362646
# 43            104984482  TRUST4                  2523.077649
# 44             73892845  TRUST4                  1217.262646
# 45             71654976  TRUST4                  1391.710745
# 46             43179989  TRUST4                    46.456705
# 47             40524817  TRUST4                     4.589780
# 48             82476159  TRUST4                     8.353929
# 49             72397468  TRUST4                     0.262440
# 50             85492431  TRUST4                     7.684891
# 51             68584414  TRUST4                    14.711797
# 52             63320771  TRUST4                     4.832537
# 53             55727841  TRUST4                     1.130494
# 54            107919183  TRUST4                     0.361382
# 55             80622502  TRUST4                    35.411950
# 56             55931661  TRUST4                     6.275515

# %%
# Number of TCR derived reads by RNA-Seq based methods per 1 million RNA-Seq reads in different repertoire types
repertoire_classes = ['T_cell_rich_monoclonal','T_cell_rich_polyclonal','T_cell_poor_monoclonal','T_cell_poor_polyclonal']
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (10,10))

ax = sns.barplot(x='class',y='TCR_derived_by_RNA_seq_tool',hue='tool',data=df,palette='muted',
                 order=repertoire_classes,alpha=0.7)
sns.stripplot(x="class",y="TCR_derived_by_RNA_seq_tool",data=df,s=8,color=".3",palette="muted",hue='tool',
              dodge=True,linewidth=1,order=repertoire_classes)
ax.set(xticklabels=["rich_mono", "rich_poly", "poor_mono", "poor_poly"])

ax.set_xlabel('Repertoire type',fontsize=20)
ax.set_ylabel('TCR derived reads from RNA-Seq per 1 million RNA-Seq reads (log)',fontsize=20)
ax.set_yscale("log")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1), handletextpad=0.1, frameon=False)
plt.setp(ax.get_legend().get_texts(), fontsize=20) 
plt.setp(ax.get_legend().get_title(), fontsize=20)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)

sns.despine()

plt.savefig("../figures/supplementary/figureS4.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS4.png",bbox_inches="tight")
plt.show()
