# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
est_reads = ['28000','13500','2600','1300','310']

# %% [markdown]
# ## MIXCR

# %%
df_MIXCR = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_MIXCR_'+reads+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)
    
    df_MIXCR = pd.merge(df_MIXCR, df_temp_aa, how='right', on=['th'])

df_MIXCR
# Out:
#             th  observed_portion_frequency_28000  \
# 0        0.000                          0.920333
# 1        0.001                          0.935638
# 2        0.002                          0.938715
# 3        0.003                          0.973352
# 4        0.004                          0.984228
# ...        ...                               ...
# 99995   99.996                               NaN
# 99996   99.997                               NaN
# 99997   99.998                               NaN
# 99998   99.999                               NaN
# 99999  100.000                               NaN
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.916505                         0.913082
# 1                              0.931772                         0.928267
# 2                              0.934902                         0.931392
# 3                              0.969765                         0.966198
# 4                              0.980909                         0.977358
# ...                                 ...                              ...
# 99995                               NaN                              NaN
# 99996                               NaN                              NaN
# 99997                               NaN                              NaN
# 99998                               NaN                              NaN
# 99999                               NaN                              NaN
#
#        observed_portion_frequency_1300  observed_portion_frequency_310
# 0                             0.912754                        0.912754
# 1                             0.927927                        0.927927
# 2                             0.931050                        0.931050
# 3                             0.965849                        0.965849
# 4                             0.977006                        0.977006
# ...                                ...                             ...
# 99995                              NaN                             NaN
# 99996                              NaN                             NaN
# 99997                              NaN                             NaN
# 99998                              NaN                             NaN
# 99999                              NaN                             NaN
#
# [100000 rows x 6 columns]

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_310'],label='310',color='#4878d0')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_MIXCR['th'],df_MIXCR['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['310','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by MIXCR')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.2,fontsize=15)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)
    
plt.savefig("../figures/supplementary/figureS11b.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS11b.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## IMREP

# %%
df_IMREP = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_IMREP_'+reads+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)

    df_IMREP = pd.merge(df_IMREP, df_temp_aa, how='right', on=['th'])

df_IMREP
# Out:
#             th  observed_portion_frequency_28000  \
# 0        0.000                          0.919882
# 1        0.001                          0.935108
# 2        0.002                          0.938141
# 3        0.003                          0.972568
# 4        0.004                          0.983350
# ...        ...                               ...
# 99995   99.996                               NaN
# 99996   99.997                               NaN
# 99997   99.998                               NaN
# 99998   99.999                               NaN
# 99999  100.000                               NaN
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.916502                         0.913037
# 1                              0.931742                         0.928220
# 2                              0.934871                         0.931345
# 3                              0.969637                         0.966132
# 4                              0.980732                         0.977279
# ...                                 ...                              ...
# 99995                               NaN                              NaN
# 99996                               NaN                              NaN
# 99997                               NaN                              NaN
# 99998                               NaN                              NaN
# 99999                               NaN                              NaN
#
#        observed_portion_frequency_1300  observed_portion_frequency_310
# 0                             0.912775                        0.912754
# 1                             0.927946                        0.927927
# 2                             0.931069                        0.931050
# 3                             0.965861                        0.965849
# 4                             0.977006                        0.977006
# ...                                ...                             ...
# 99995                              NaN                             NaN
# 99996                              NaN                             NaN
# 99997                              NaN                             NaN
# 99998                              NaN                             NaN
# 99999                              NaN                             NaN
#
# [100000 rows x 6 columns]

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_310'],label='310',color='#4878d0')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_IMREP['th'],df_IMREP['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['310','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by IMREP')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.2,fontsize=15)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)
    
plt.savefig("../figures/supplementary/figureS11c.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS11c.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TRUST4

# %%
df_TRUST4 = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_TRUST4_'+reads+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)

    df_TRUST4 = pd.merge(df_TRUST4, df_temp_aa, how='right', on=['th'])

df_TRUST4
# Out:
#             th  observed_portion_frequency_28000  \
# 0        0.000                          0.920553
# 1        0.001                          0.935813
# 2        0.002                          0.938844
# 3        0.003                          0.973396
# 4        0.004                          0.984256
# ...        ...                               ...
# 99995   99.996                               NaN
# 99996   99.997                               NaN
# 99997   99.998                               NaN
# 99998   99.999                               NaN
# 99999  100.000                               NaN
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.917052                         0.913490
# 1                              0.932297                         0.928689
# 2                              0.935417                         0.931812
# 3                              0.970214                         0.966597
# 4                              0.981292                         0.977745
# ...                                 ...                              ...
# 99995                               NaN                              NaN
# 99996                               NaN                              NaN
# 99997                               NaN                              NaN
# 99998                               NaN                              NaN
# 99999                               NaN                              NaN
#
#        observed_portion_frequency_1300  observed_portion_frequency_310
# 0                             0.913141                        0.912754
# 1                             0.928327                        0.927927
# 2                             0.931453                        0.931050
# 3                             0.966247                        0.965849
# 4                             0.977394                        0.977006
# ...                                ...                             ...
# 99995                              NaN                             NaN
# 99996                              NaN                             NaN
# 99997                              NaN                             NaN
# 99998                              NaN                             NaN
# 99999                              NaN                             NaN
#
# [100000 rows x 6 columns]

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_310'],label='310',color='#4878d0')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_TRUST4['th'],df_TRUST4['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['310','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by TRUST4')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.2,fontsize=15)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)
    
plt.savefig("../figures/supplementary/figureS11d.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS11d.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## CATT

# %%
df_CATT = pd.DataFrame(columns=['th'])

for reads in est_reads: 
    df_temp_aa = pd.read_csv('../summary_data/subsample/capturing_per_reads/capturing_CATT_'+reads+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
    df_temp_aa.rename(columns={'observed_portion_frequency':'observed_portion_frequency_'+reads}, inplace=True)
    
    df_CATT = pd.merge(df_CATT, df_temp_aa, how='right', on=['th'])

df_CATT
# Out:
#             th  observed_portion_frequency_28000  \
# 0        0.000                          0.919564
# 1        0.001                          0.934851
# 2        0.002                          0.937961
# 3        0.003                          0.972717
# 4        0.004                          0.983620
# ...        ...                               ...
# 99995   99.996                               NaN
# 99996   99.997                               NaN
# 99997   99.998                               NaN
# 99998   99.999                               NaN
# 99999  100.000                               NaN
#
#        observed_portion_frequency_13500  observed_portion_frequency_2600  \
# 0                              0.915858                         0.913013
# 1                              0.931093                         0.928198
# 2                              0.934218                         0.931323
# 3                              0.969071                         0.966125
# 4                              0.980211                         0.977284
# ...                                 ...                              ...
# 99995                               NaN                              NaN
# 99996                               NaN                              NaN
# 99997                               NaN                              NaN
# 99998                               NaN                              NaN
# 99999                               NaN                              NaN
#
#        observed_portion_frequency_1300  observed_portion_frequency_310
# 0                             0.912754                        0.912754
# 1                             0.927927                        0.927927
# 2                             0.931050                        0.931050
# 3                             0.965849                        0.965849
# 4                             0.977006                        0.977006
# ...                                ...                             ...
# 99995                              NaN                             NaN
# 99996                              NaN                             NaN
# 99997                              NaN                             NaN
# 99998                              NaN                             NaN
# 99999                              NaN                             NaN
#
# [100000 rows x 6 columns]

# %%
sns.set_style("white") 
sns.set_context("talk")  
    
fig, ax = plt.subplots(figsize=(5, 5))

sns.lineplot(df_CATT['th'],df_CATT['observed_portion_frequency_310'],label='310',color='#4878d0')
sns.lineplot(df_CATT['th'],df_CATT['observed_portion_frequency_1300'],label='1300',color='#ee854a')
sns.lineplot(df_CATT['th'],df_CATT['observed_portion_frequency_2600'],label='2600',color='#6acc64')
sns.lineplot(df_CATT['th'],df_CATT['observed_portion_frequency_13500'],label='13500',color='#d65f5f')
sns.lineplot(df_CATT['th'],df_CATT['observed_portion_frequency_28000'],label='28000',color='#956cb4')
    
ax.legend(['310','1300','2600','13500','28000'])
  
plt.legend(bbox_to_anchor=(0.2,1), frameon=False, ncol=3, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by CATT')
ax.set_xlabel('Clonotype frequency (%)')
plt.title('Estimated reads',y=1.2,fontsize=15)
ax.set_xlim(0,0.1)
ax.set_ylim(0.98,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS11e.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS11e.png",bbox_inches="tight")

plt.show()
