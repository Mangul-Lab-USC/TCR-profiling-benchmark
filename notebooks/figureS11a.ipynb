# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../summary_data/subsample/subsample_diversity.csv")
df
# Out:
#       Sample  shannon_index_TCR  shannon_index_tool    tool  \
# 0   sample01           1.072675            0.388575   MIXCR
# 1   sample01           1.072675            0.446116   IMREP
# 2   sample01           1.072675            0.440557  TRUST4
# 3   sample01           1.072675            0.439513    CATT
# 4   sample01           1.072675            0.354839   MIXCR
# 5   sample01           1.072675            0.406557   IMREP
# 6   sample01           1.072675            0.402618  TRUST4
# 7   sample01           1.072675            0.410509    CATT
# 8   sample01           1.072675            0.348609   MIXCR
# 9   sample01           1.072675            0.364779   IMREP
# 10  sample01           1.072675            0.356716  TRUST4
# 11  sample01           1.072675            0.396529    CATT
# 12  sample01           1.072675            0.348820   MIXCR
# 13  sample01           1.072675            0.355726   IMREP
# 14  sample01           1.072675            0.350471  TRUST4
# ...

# %%
sns.set_style('white')
sns.set_context('talk')

fig, ax = plt.subplots(figsize=(10, 10))
ax = sns.barplot(data=df, x="tool", y="SDI_absolute_error", hue="est_reads", palette="muted")
ax.set(ylim=(0,1))

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:5], labels[0:5], bbox_to_anchor=(0.7, 0.7), frameon=False, title='Estimated reads')

ax.set_xlabel('Tools',fontsize=20)
ax.set_ylabel('Absolute error of SDI',fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.setp(ax.get_legend().get_texts(), fontsize=20) 
plt.setp(ax.get_legend().get_title(), fontsize=20)
sns.despine()

plt.savefig("../figures/supplementary/figureS11a.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS11a.png",bbox_inches="tight")

plt.show()

# %%
mean_diversity_combined = df.groupby(["tool","est_reads"])["SDI_absolute_error"].mean().reset_index()
mean_diversity_combined = mean_diversity_combined.sort_values('est_reads')
mean_diversity_combined
# Out:
#       tool  est_reads  SDI_absolute_error
# 0     CATT        310            0.597869
# 5    IMREP        310            0.664181
# 10   MIXCR        310            0.635256
# 15  TRUST4        310            0.661779
# 1     CATT       1300            0.578189
# 6    IMREP       1300            0.650671
# 11   MIXCR       1300            0.638968
# 16  TRUST4       1300            0.640767
# 2     CATT       2600            0.567473
# 17  TRUST4       2600            0.625515
# 7    IMREP       2600            0.637596
# 12   MIXCR       2600            0.637319
# 3     CATT      13500            0.543584
# 8    IMREP      13500            0.570084
# 18  TRUST4      13500            0.571037
# 13   MIXCR      13500            0.620211
# 9    IMREP      28000            0.450402
# 4     CATT      28000            0.503502
# 14   MIXCR      28000            0.561255
# 19  TRUST4      28000            0.502384
