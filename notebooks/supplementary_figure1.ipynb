# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../summary_data/original/all_tools_TRB_reads.csv")
df
# Out:
#                           Sample           tissue  tissue_type  \
# 0              MP-11-28-12RNA_S2             PBMC  T_cell_rich
# 1          CMT-baseline1C_CAGATC         melanoma  T_cell_poor
# 2            LEK-baseline_CGATGT         melanoma  T_cell_poor
# 3           LEK-OT110712A_CCGTCC         melanoma  T_cell_poor
# 4           HM-baseline1C_CGATGT         melanoma  T_cell_poor
# 5                      PT0310_S9         melanoma  T_cell_poor
# 6                    PT0112-B_S3         melanoma  T_cell_poor
# 7                    PT0285-B_S5         melanoma  T_cell_poor
# 8         JSSBaseline-RNA_GTGAAA         melanoma  T_cell_poor
# 9            RAS-baseline_TGACCA         melanoma  T_cell_poor
# 10  ESO1-sorted-T-cells_S13_L007             PBMC  T_cell_rich
# 11  INY1-sorted-T-cells_S14_L007             PBMC  T_cell_rich
# 12  INY2-sorted-T-cells_S15_L007             PBMC  T_cell_rich
# 13                  TR2-PBMC_S12             PBMC  T_cell_rich
# 14            SAR-11-14-12RNA_S1             PBMC  T_cell_rich
# 15                    SRR5233637  small_intestine  T_cell_poor
# 16                    SRR5233639       lymph_node  T_cell_rich
# 17                  TCGA-CZ-4862           kidney  T_cell_poor
# 18                  TCGA-CZ-5463           kidney  T_cell_poor
# 19                  TCGA-CZ-5985           kidney  T_cell_poor
# 20             MP-11-28-12RNA_S2             PBMC  T_cell_rich
# 21         CMT-baseline1C_CAGATC         melanoma  T_cell_poor
# 22           LEK-baseline_CGATGT         melanoma  T_cell_poor
# 23          LEK-OT110712A_CCGTCC         melanoma  T_cell_poor
# 24          HM-baseline1C_CGATGT         melanoma  T_cell_poor
# 25                     PT0310_S9         melanoma  T_cell_poor
# 26                   PT0112-B_S3         melanoma  T_cell_poor
# 27                   PT0285-B_S5         melanoma  T_cell_poor
# 28        JSSBaseline-RNA_GTGAAA         melanoma  T_cell_poor
# 29           RAS-baseline_TGACCA         melanoma  T_cell_poor
# 30  ESO1-sorted-T-cells_S13_L007             PBMC  T_cell_rich
# 31  INY1-sorted-T-cells_S14_L007             PBMC  T_cell_rich
# 32  INY2-sorted-T-cells_S15_L007             PBMC  T_cell_rich
# 33                  TR2-PBMC_S12             PBMC  T_cell_rich
# 34            SAR-11-14-12RNA_S1             PBMC  T_cell_rich
# 35                    SRR5233637  small_intestine  T_cell_poor
# 36                    SRR5233639       lymph_node  T_cell_rich
# 37                  TCGA-CZ-4862           kidney  T_cell_poor
# 38                  TCGA-CZ-5463           kidney  T_cell_poor
# 39                  TCGA-CZ-5985           kidney  T_cell_poor
# 40             MP-11-28-12RNA_S2             PBMC  T_cell_rich
# 41         CMT-baseline1C_CAGATC         melanoma  T_cell_poor
# 42           LEK-baseline_CGATGT         melanoma  T_cell_poor
# 43          LEK-OT110712A_CCGTCC         melanoma  T_cell_poor
# 44          HM-baseline1C_CGATGT         melanoma  T_cell_poor
# 45                     PT0310_S9         melanoma  T_cell_poor
# 46                   PT0112-B_S3         melanoma  T_cell_poor
# 47                   PT0285-B_S5         melanoma  T_cell_poor
# 48        JSSBaseline-RNA_GTGAAA         melanoma  T_cell_poor
# 49           RAS-baseline_TGACCA         melanoma  T_cell_poor
# 50  ESO1-sorted-T-cells_S13_L007             PBMC  T_cell_rich
# 51  INY1-sorted-T-cells_S14_L007             PBMC  T_cell_rich
# 52  INY2-sorted-T-cells_S15_L007             PBMC  T_cell_rich
# 53                  TR2-PBMC_S12             PBMC  T_cell_rich
# 54            SAR-11-14-12RNA_S1             PBMC  T_cell_rich
# 55                    SRR5233637  small_intestine  T_cell_poor
# 56                    SRR5233639       lymph_node  T_cell_rich
# 57                  TCGA-CZ-4862           kidney  T_cell_poor
# 58                  TCGA-CZ-5463           kidney  T_cell_poor
# 59                  TCGA-CZ-5985           kidney  T_cell_poor
#
#    repertoire_type                   class  total_reads_TCR  total_reads_tool  \
# 0       polyclonal  T_cell_rich_polyclonal          18617.0              55.0
# 1       polyclonal  T_cell_poor_polyclonal         906121.0              91.0
# 2       polyclonal  T_cell_poor_polyclonal        1769522.0              59.0
# 3       polyclonal  T_cell_poor_polyclonal        1157845.0             310.0
# 4       polyclonal  T_cell_poor_polyclonal        1257571.0               0.0
# 5       polyclonal  T_cell_poor_polyclonal          12954.0            1071.0
# 6       polyclonal  T_cell_poor_polyclonal        1006220.0              12.0
# 7       polyclonal  T_cell_poor_polyclonal         292828.0               8.0
# 8       polyclonal  T_cell_poor_polyclonal        1408590.0             150.0
# 9       polyclonal  T_cell_poor_polyclonal         749686.0             113.0
# 10      monoclonal  T_cell_rich_monoclonal          90577.0          132472.0
# 11      monoclonal  T_cell_rich_monoclonal          87762.0           41370.0
# 12      monoclonal  T_cell_rich_monoclonal         305953.0           52066.0
# 13      polyclonal  T_cell_rich_polyclonal          36666.0            2572.0
# 14      polyclonal  T_cell_rich_polyclonal         104779.0             158.0
# 15      polyclonal  T_cell_poor_polyclonal        3047629.0              84.0
# 16      polyclonal  T_cell_rich_polyclonal        3256697.0            1346.0
# 17      polyclonal  T_cell_poor_polyclonal          16784.0               0.0
# 18      polyclonal  T_cell_poor_polyclonal            806.0               0.0
# 19      polyclonal  T_cell_poor_polyclonal          12998.0               0.0
# 20      polyclonal  T_cell_rich_polyclonal          18617.0             111.0
# 21      polyclonal  T_cell_poor_polyclonal         906121.0             231.0
# 22      polyclonal  T_cell_poor_polyclonal        1769522.0              71.0
# 23      polyclonal  T_cell_poor_polyclonal        1157845.0             334.0
# 24      polyclonal  T_cell_poor_polyclonal        1257571.0               2.0
# 25      polyclonal  T_cell_poor_polyclonal          12954.0             844.0
# 26      polyclonal  T_cell_poor_polyclonal        1006220.0              31.0
# 27      polyclonal  T_cell_poor_polyclonal         292828.0              10.0
# 28      polyclonal  T_cell_poor_polyclonal        1408590.0             259.0
# 29      polyclonal  T_cell_poor_polyclonal         749686.0             152.0
# 30      monoclonal  T_cell_rich_monoclonal          90577.0          219185.0
# 31      monoclonal  T_cell_rich_monoclonal          87762.0           57700.0
# 32      monoclonal  T_cell_rich_monoclonal         305953.0           64914.0
# 33      polyclonal  T_cell_rich_polyclonal          36666.0            9888.0
# 34      polyclonal  T_cell_rich_polyclonal         104779.0            1354.0
# 35      polyclonal  T_cell_poor_polyclonal        3047629.0             315.0
# 36      polyclonal  T_cell_rich_polyclonal        3256697.0            6143.0
# 37      polyclonal  T_cell_poor_polyclonal          16784.0              50.0
# 38      polyclonal  T_cell_poor_polyclonal            806.0              16.0
# 39      polyclonal  T_cell_poor_polyclonal          12998.0              23.0
# 40      polyclonal  T_cell_rich_polyclonal          18617.0             186.0
# 41      polyclonal  T_cell_poor_polyclonal         906121.0             689.0
# 42      polyclonal  T_cell_poor_polyclonal        1769522.0             306.0
# 43      polyclonal  T_cell_poor_polyclonal        1157845.0            1009.0
# 44      polyclonal  T_cell_poor_polyclonal        1257571.0              19.0
# 45      polyclonal  T_cell_poor_polyclonal          12954.0            2855.0
# 46      polyclonal  T_cell_poor_polyclonal        1006220.0              63.0
# 47      polyclonal  T_cell_poor_polyclonal         292828.0              39.0
# 48      polyclonal  T_cell_poor_polyclonal        1408590.0             657.0
# 49      polyclonal  T_cell_poor_polyclonal         749686.0             351.0
# 50      monoclonal  T_cell_rich_monoclonal          90577.0          264884.0
# 51      monoclonal  T_cell_rich_monoclonal          87762.0           89947.0
# 52      monoclonal  T_cell_rich_monoclonal         305953.0           99723.0
# 53      polyclonal  T_cell_rich_polyclonal          36666.0           13022.0
# 54      polyclonal  T_cell_rich_polyclonal         104779.0            2006.0
# 55      polyclonal  T_cell_poor_polyclonal        3047629.0             544.0
# 56      polyclonal  T_cell_rich_polyclonal        3256697.0            9054.0
# 57      polyclonal  T_cell_poor_polyclonal          16784.0             710.0
# 58      polyclonal  T_cell_poor_polyclonal            806.0             366.0
# 59      polyclonal  T_cell_poor_polyclonal          12998.0             282.0
#
#     total_reads_RNA_seq    tool  TCR_derived_by_RNA_seq_tool
# 0              40524817   MIXCR                     1.357193
# 1              82476159   MIXCR                     1.103349
# 2              63320771   MIXCR                     0.931764
# 3              68584414   MIXCR                     4.519977
# 4              72397468   MIXCR                     0.000000
# 5              80622502   MIXCR                    13.284133
# 6              55727841   MIXCR                     0.215332
# 7             107919183   MIXCR                     0.074130
# 8              85492431   MIXCR                     1.754541
# 9              55931661   MIXCR                     2.020323
# 10            104984482   MIXCR                  1261.824581
# 11             73892845   MIXCR                   559.864761
# 12             71654976   MIXCR                   726.620856
# 13             79372504   MIXCR                    32.404169
# 14             43179989   MIXCR                     3.659102
# 15             72720367   MIXCR                     1.155110
# 16             65998918   MIXCR                    20.394274
# 17             58529923   MIXCR                     0.000000
# 18            122632451   MIXCR                     0.000000
# 19             83862519   MIXCR                     0.000000
# 20             40524817   IMREP                     2.739062
# 21             82476159   IMREP                     2.800809
# 22             63320771   IMREP                     1.121275
# 23             68584414   IMREP                     4.869911
# 24             72397468   IMREP                     0.027625
# 25             80622502   IMREP                    10.468541
# 26             55727841   IMREP                     0.556275
# 27            107919183   IMREP                     0.092662
# 28             85492431   IMREP                     3.029508
# 29             55931661   IMREP                     2.717602
# 30            104984482   IMREP                  2087.784745
# 31             73892845   IMREP                   780.860447
# 32             71654976   IMREP                   905.924524
# 33             79372504   IMREP                   124.577146
# 34             43179989   IMREP                    31.357118
# 35             72720367   IMREP                     4.331661
# 36             65998918   IMREP                    93.077283
# 37             58529923   IMREP                     0.854264
# 38            122632451   IMREP                     0.130471
# 39             83862519   IMREP                     0.274258
# 40             40524817  TRUST4                     4.589780
# 41             82476159  TRUST4                     8.353929
# 42             63320771  TRUST4                     4.832537
# 43             68584414  TRUST4                    14.711797
# 44             72397468  TRUST4                     0.262440
# 45             80622502  TRUST4                    35.411950
# 46             55727841  TRUST4                     1.130494
# 47            107919183  TRUST4                     0.361382
# 48             85492431  TRUST4                     7.684891
# 49             55931661  TRUST4                     6.275515
# 50            104984482  TRUST4                  2523.077649
# 51             73892845  TRUST4                  1217.262646
# 52             71654976  TRUST4                  1391.710745
# 53             79372504  TRUST4                   164.061852
# 54             43179989  TRUST4                    46.456705
# 55             72720367  TRUST4                     7.480710
# 56             65998918  TRUST4                   137.184067
# 57             58529923  TRUST4                    12.130547
# 58            122632451  TRUST4                     2.984528
# 59             83862519  TRUST4                     3.362646

# %%
# Number of TCR derived reads by RNA-Seq based methods per 1 million RNA-Seq reads in different tissue types 
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (10,10))

ax = sns.boxplot(x='tissue',y='TCR_derived_by_RNA_seq_tool',hue='tool',data=df,palette='muted',
                 order=['PBMC','lymph_node','melanoma','small_intestine','kidney'],boxprops=dict(alpha=.7))
sns.stripplot(x="tissue",y="TCR_derived_by_RNA_seq_tool",data=df,s = 5,color=".3",palette="muted",hue='tool',
              dodge=True,linewidth=1,order=['PBMC','lymph_node','melanoma','small_intestine','kidney'])

ax.set_xlabel('Tissue type',fontsize=15)
ax.set_ylabel('TCR derived reads from RNA-Seq per 1 million RNA-Seq reads(log)',fontsize=15)
ax.set_yscale("log")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1))
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)

sns.despine()
plt.show()

# %%
# Number of TCR derived reads by RNA-Seq based methods per 1 million RNA-Seq reads in different repertoire types
repertoire_classes = ['T_cell_rich_monoclonal','T_cell_rich_polyclonal','T_cell_poor_polyclonal']
sns.set_style("white") 
sns.set_context("talk")  

ax = plt.subplots(figsize = (10,10))

ax = sns.boxplot(x='class',y='TCR_derived_by_RNA_seq_tool',hue='tool',data=df,palette='muted',
                 order=repertoire_classes,boxprops=dict(alpha=.7))
sns.stripplot(x="class",y="TCR_derived_by_RNA_seq_tool",data=df,s = 5,color=".3",palette="muted",hue='tool',
              dodge=True,linewidth=1,order=repertoire_classes)

ax.set_xlabel('Repertoire type',fontsize=15)
ax.set_ylabel('TCR derived reads from RNA-Seq per 1 million RNA-Seq reads(log)',fontsize=15)
ax.set_yscale("log")

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1, 1))
plt.setp(ax.get_legend().get_texts(), fontsize=15) 
plt.setp(ax.get_legend().get_title(), fontsize=15)
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)

sns.despine()
plt.show()
