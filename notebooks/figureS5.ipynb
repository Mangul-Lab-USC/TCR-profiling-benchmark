# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
samples = ['sample01','sample02','sample03','sample04','sample05','sample06','sample07','sample08',
           'sample09','sample10','sample11','sample12','sample13','sample14',
            'SRR5233639','SRR5233637','TCGA-CZ-4862','TCGA-CZ-5463','TCGA-CZ-5985']

# %%
columns = ['th', 'observed_portion_frequency', 'sample']
df_MIXCR = pd.DataFrame(columns=columns)

for sample in samples: 
    df_temp_aa = pd.read_csv('../summary_data/original/capturing_per_sample/capturing_MIXCR_'+sample+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
    
    df_temp_aa['sample'] = sample

    df_MIXCR = pd.concat([df_MIXCR, df_temp_aa], ignore_index=True, sort=False)
    df_MIXCR['tool'] = 'MIXCR'

# %%
columns = ['th', 'observed_portion_frequency', 'sample']
df_IMREP = pd.DataFrame(columns=columns)

for sample in samples: 
    df_temp_aa = pd.read_csv('../summary_data/original/capturing_per_sample/capturing_IMREP_'+sample+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
    
    df_temp_aa['sample'] = sample

    df_IMREP = pd.concat([df_IMREP, df_temp_aa], ignore_index=True,sort=False)
    df_IMREP['tool'] = 'IMREP'

# %%
columns = ['th', 'observed_portion_frequency', 'sample']
df_TRUST4 = pd.DataFrame(columns=columns)

for sample in samples: 
    df_temp_aa = pd.read_csv('../summary_data/original/capturing_per_sample/capturing_TRUST4_'+sample+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
   
    df_temp_aa['sample'] = sample

    df_TRUST4 = pd.concat([df_TRUST4, df_temp_aa], ignore_index=True, sort=False)
    df_TRUST4['tool'] = 'TRUST4'

# %%
columns = ['th', 'observed_portion_frequency', 'sample']
df_CATT = pd.DataFrame(columns=columns)

for sample in samples: 
    df_temp_aa = pd.read_csv('../summary_data/original/capturing_per_sample/capturing_CATT_'+sample+'.csv')
    df_temp_aa['th'] = df_temp_aa['th']*100
   
    df_temp_aa['sample'] = sample

    df_CATT = pd.concat([df_CATT, df_temp_aa], ignore_index=True, sort=False)
    df_CATT['tool'] = 'CATT'

# %%
df_combined = pd.concat([df_MIXCR,df_IMREP,df_TRUST4,df_CATT], ignore_index=True, sort=False)
df_combined['th'] = df_combined['th']
df_combined
# Out:
#               th  observed_portion_frequency        sample   tool
# 0          0.000                    0.927752      sample01  MIXCR
# 1          0.001                    0.927752      sample01  MIXCR
# 2          0.002                    0.927752      sample01  MIXCR
# 3          0.003                    0.966086      sample01  MIXCR
# 4          0.004                    0.980052      sample01  MIXCR
# ...          ...                         ...           ...    ...
# 7599995   99.996                         NaN  TCGA-CZ-5985   CATT
# 7599996   99.997                         NaN  TCGA-CZ-5985   CATT
# 7599997   99.998                         NaN  TCGA-CZ-5985   CATT
# 7599998   99.999                         NaN  TCGA-CZ-5985   CATT
# 7599999  100.000                         NaN  TCGA-CZ-5985   CATT
#
# [7600000 rows x 4 columns]

# %% [markdown]
# ## sample01

# %%
df_sample01 = df_combined.loc[df_combined['sample'] == 'sample01']

sample01_MIXCR = df_sample01.loc[df_sample01['tool'] == 'MIXCR']
sample01_IMREP = df_sample01.loc[df_sample01['tool'] == 'IMREP']
sample01_TRUST4 = df_sample01.loc[df_sample01['tool'] == 'TRUST4']
sample01_CATT = df_sample01.loc[df_sample01['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample01_MIXCR['th'], sample01_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample01_IMREP['th'], sample01_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample01_TRUST4['th'], sample01_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample01_CATT['th'], sample01_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample01',y=1.1,fontsize=15)
ax.set_ylim(0.925,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5a.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5a.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample02

# %%
df_sample02 = df_combined.loc[df_combined['sample'] == 'sample02']

sample02_MIXCR = df_sample02.loc[df_sample02['tool'] == 'MIXCR']
sample02_IMREP = df_sample02.loc[df_sample02['tool'] == 'IMREP']
sample02_TRUST4 = df_sample02.loc[df_sample02['tool'] == 'TRUST4']
sample02_CATT = df_sample02.loc[df_sample02['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample02_MIXCR['th'], sample02_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample02_IMREP['th'], sample02_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample02_TRUST4['th'], sample02_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample02_CATT['th'], sample02_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample02',y=1.1,fontsize=15)
ax.set_ylim(0.925,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5b.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5b.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample03

# %%
df_sample03 = df_combined.loc[df_combined['sample'] == 'sample03']

sample03_MIXCR = df_sample03.loc[df_sample03['tool'] == 'MIXCR']
sample03_IMREP = df_sample03.loc[df_sample03['tool'] == 'IMREP']
sample03_TRUST4 = df_sample03.loc[df_sample03['tool'] == 'TRUST4']
sample03_CATT = df_sample03.loc[df_sample03['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample03_MIXCR['th'], sample03_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample03_IMREP['th'], sample03_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample03_TRUST4['th'], sample03_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample03_CATT['th'], sample03_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample03',y=1.1,fontsize=15)
ax.set_ylim(0.925,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5c.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5c.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample04

# %%
df_sample04 = df_combined.loc[df_combined['sample'] == 'sample04']

sample04_MIXCR = df_sample04.loc[df_sample04['tool'] == 'MIXCR']
sample04_IMREP = df_sample04.loc[df_sample04['tool'] == 'IMREP']
sample04_TRUST4 = df_sample04.loc[df_sample04['tool'] == 'TRUST4']
sample04_CATT = df_sample04.loc[df_sample04['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample04_MIXCR['th'], sample04_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample04_IMREP['th'], sample04_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample04_TRUST4['th'], sample04_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample04_CATT['th'], sample04_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample04',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5d.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5d.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample05

# %%
df_sample05 = df_combined.loc[df_combined['sample'] == 'sample05']

sample05_MIXCR = df_sample05.loc[df_sample05['tool'] == 'MIXCR']
sample05_IMREP = df_sample05.loc[df_sample05['tool'] == 'IMREP']
sample05_TRUST4 = df_sample05.loc[df_sample05['tool'] == 'TRUST4']
sample05_CATT = df_sample05.loc[df_sample05['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample05_MIXCR['th'], sample05_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample05_IMREP['th'], sample05_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample05_TRUST4['th'], sample05_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample05_CATT['th'], sample05_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample05',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5e.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5e.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## SRR5233639

# %%
df_SRR5233639 = df_combined.loc[df_combined['sample'] == 'SRR5233639']

SRR5233639_MIXCR = df_SRR5233639.loc[df_SRR5233639['tool'] == 'MIXCR']
SRR5233639_IMREP = df_SRR5233639.loc[df_SRR5233639['tool'] == 'IMREP']
SRR5233639_TRUST4 = df_SRR5233639.loc[df_SRR5233639['tool'] == 'TRUST4']
SRR5233639_CATT = df_SRR5233639.loc[df_SRR5233639['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(SRR5233639_MIXCR['th'], SRR5233639_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(SRR5233639_IMREP['th'], SRR5233639_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(SRR5233639_TRUST4['th'], SRR5233639_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(SRR5233639_CATT['th'], SRR5233639_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('SRR5233639',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5f.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5f.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample13

# %%
df_sample13 = df_combined.loc[df_combined['sample'] == 'sample13']

sample13_MIXCR = df_sample13.loc[df_sample13['tool'] == 'MIXCR']
sample13_IMREP = df_sample13.loc[df_sample13['tool'] == 'IMREP']
sample13_TRUST4 = df_sample13.loc[df_sample13['tool'] == 'TRUST4']
sample13_CATT = df_sample13.loc[df_sample13['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample13_MIXCR['th'], sample13_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample13_IMREP['th'], sample13_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample13_TRUST4['th'], sample13_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample13_CATT['th'], sample13_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample13',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5g.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5g.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample06

# %%
df_sample06 = df_combined.loc[df_combined['sample'] == 'sample06']

sample06_MIXCR = df_sample06.loc[df_sample06['tool'] == 'MIXCR']
sample06_IMREP = df_sample06.loc[df_sample06['tool'] == 'IMREP']
sample06_TRUST4 = df_sample06.loc[df_sample06['tool'] == 'TRUST4']
sample06_CATT = df_sample06.loc[df_sample06['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample06_MIXCR['th'], sample06_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample06_IMREP['th'], sample06_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample06_TRUST4['th'], sample06_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample06_CATT['th'], sample06_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample06',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5h.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5h.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample07

# %%
df_sample07 = df_combined.loc[df_combined['sample'] == 'sample07']

sample07_MIXCR = df_sample07.loc[df_sample07['tool'] == 'MIXCR']
sample07_IMREP = df_sample07.loc[df_sample07['tool'] == 'IMREP']
sample07_TRUST4 = df_sample07.loc[df_sample07['tool'] == 'TRUST4']
sample07_CATT = df_sample07.loc[df_sample07['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample07_MIXCR['th'], sample07_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample07_IMREP['th'], sample07_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample07_TRUST4['th'], sample07_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample07_CATT['th'], sample07_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample07',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5i.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5i.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample08

# %%
df_sample08 = df_combined.loc[df_combined['sample'] == 'sample08']

sample08_MIXCR = df_sample08.loc[df_sample08['tool'] == 'MIXCR']
sample08_IMREP = df_sample08.loc[df_sample08['tool'] == 'IMREP']
sample08_TRUST4 = df_sample08.loc[df_sample08['tool'] == 'TRUST4']
sample08_CATT = df_sample08.loc[df_sample08['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample08_MIXCR['th'], sample08_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample08_IMREP['th'], sample08_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample08_TRUST4['th'], sample08_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample08_CATT['th'], sample08_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample08',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5j.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5j.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample09

# %%
df_sample09 = df_combined.loc[df_combined['sample'] == 'sample09']

sample09_MIXCR = df_sample09.loc[df_sample09['tool'] == 'MIXCR']
sample09_IMREP = df_sample09.loc[df_sample09['tool'] == 'IMREP']
sample09_TRUST4 = df_sample09.loc[df_sample09['tool'] == 'TRUST4']
sample09_CATT = df_sample09.loc[df_sample09['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample09_MIXCR['th'], sample09_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample09_IMREP['th'], sample09_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample09_TRUST4['th'], sample09_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample09_CATT['th'], sample09_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample09',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5k.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5k.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample10

# %%
df_sample10 = df_combined.loc[df_combined['sample'] == 'sample10']

sample10_MIXCR = df_sample10.loc[df_sample10['tool'] == 'MIXCR']
sample10_IMREP = df_sample10.loc[df_sample10['tool'] == 'IMREP']
sample10_TRUST4 = df_sample10.loc[df_sample10['tool'] == 'TRUST4']
sample10_CATT = df_sample10.loc[df_sample10['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample10_MIXCR['th'], sample10_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample10_IMREP['th'], sample10_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample10_TRUST4['th'], sample10_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample10_CATT['th'], sample10_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample10',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5l.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5l.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample11

# %%
df_sample11 = df_combined.loc[df_combined['sample'] == 'sample11']

sample11_MIXCR = df_sample11.loc[df_sample11['tool'] == 'MIXCR']
sample11_IMREP = df_sample11.loc[df_sample11['tool'] == 'IMREP']
sample11_TRUST4 = df_sample11.loc[df_sample11['tool'] == 'TRUST4']
sample11_CATT = df_sample11.loc[df_sample11['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample11_MIXCR['th'], sample11_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample11_IMREP['th'], sample11_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample11_TRUST4['th'], sample11_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample11_CATT['th'], sample11_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample11',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5m.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5m.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample12

# %%
df_sample12 = df_combined.loc[df_combined['sample'] == 'sample12']

sample12_MIXCR = df_sample12.loc[df_sample12['tool'] == 'MIXCR']
sample12_IMREP = df_sample12.loc[df_sample12['tool'] == 'IMREP']
sample12_TRUST4 = df_sample12.loc[df_sample12['tool'] == 'TRUST4']
sample12_CATT = df_sample12.loc[df_sample12['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample12_MIXCR['th'], sample12_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample12_IMREP['th'], sample12_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample12_TRUST4['th'], sample12_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample12_CATT['th'], sample12_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample12',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5n.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5n.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## sample14

# %%
df_sample14 = df_combined.loc[df_combined['sample'] == 'sample14']

sample14_MIXCR = df_sample14.loc[df_sample14['tool'] == 'MIXCR']
sample14_IMREP = df_sample14.loc[df_sample14['tool'] == 'IMREP']
sample14_TRUST4 = df_sample14.loc[df_sample14['tool'] == 'TRUST4']
sample14_CATT = df_sample14.loc[df_sample14['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(sample14_MIXCR['th'], sample14_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(sample14_IMREP['th'], sample14_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(sample14_TRUST4['th'], sample14_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(sample14_CATT['th'], sample14_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('sample14',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5o.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5o.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## SRR5233637

# %%
df_SRR5233637 = df_combined.loc[df_combined['sample'] == 'SRR5233637']

SRR5233637_MIXCR = df_SRR5233637.loc[df_SRR5233637['tool'] == 'MIXCR']
SRR5233637_IMREP = df_SRR5233637.loc[df_SRR5233637['tool'] == 'IMREP']
SRR5233637_TRUST4 = df_SRR5233637.loc[df_SRR5233637['tool'] == 'TRUST4']
SRR5233637_CATT = df_SRR5233637.loc[df_SRR5233637['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(SRR5233637_MIXCR['th'], SRR5233637_MIXCR['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(SRR5233637_IMREP['th'], SRR5233637_IMREP['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(SRR5233637_TRUST4['th'], SRR5233637_TRUST4['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(SRR5233637_CATT['th'], SRR5233637_CATT['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('SRR5233637',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5p.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5p.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TCGA-CZ-4862

# %%
df_4862 = df_combined.loc[df_combined['sample'] == 'TCGA-CZ-4862']

MIXCR_4862 = df_4862.loc[df_4862['tool'] == 'MIXCR']
IMREP_4862 = df_4862.loc[df_4862['tool'] == 'IMREP']
TRUST4_4862 = df_4862.loc[df_4862['tool'] == 'TRUST4']
CATT_4862 = df_4862.loc[df_4862['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(MIXCR_4862['th'], MIXCR_4862['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(IMREP_4862['th'], IMREP_4862['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(TRUST4_4862['th'], TRUST4_4862['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(CATT_4862['th'], CATT_4862['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('TCGA-CZ-4862',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5q.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5q.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TCGA-CZ-5463

# %%
df_5463 = df_combined.loc[df_combined['sample'] == 'TCGA-CZ-5463']

MIXCR_5463 = df_5463.loc[df_5463['tool'] == 'MIXCR']
IMREP_5463 = df_5463.loc[df_5463['tool'] == 'IMREP']
TRUST4_5463 = df_5463.loc[df_5463['tool'] == 'TRUST4']
CATT_5463 = df_5463.loc[df_5463['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(MIXCR_5463['th'], MIXCR_5463['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(IMREP_5463['th'], IMREP_5463['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(TRUST4_5463['th'], TRUST4_5463['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(CATT_5463['th'], CATT_5463['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('TCGA-CZ-5463',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5r.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5r.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## TCGA-CZ-5985

# %%
df_5985 = df_combined.loc[df_combined['sample'] == 'TCGA-CZ-5985']

MIXCR_5985 = df_5985.loc[df_5985['tool'] == 'MIXCR']
IMREP_5985 = df_5985.loc[df_5985['tool'] == 'IMREP']
TRUST4_5985 = df_5985.loc[df_5985['tool'] == 'TRUST4']
CATT_5985 = df_5985.loc[df_5985['tool'] == 'CATT']

sns.set_style("white") 
sns.set_context("talk")  

fig, ax = plt.subplots(figsize=(5, 5))
sns.lineplot(MIXCR_5985['th'], MIXCR_5985['observed_portion_frequency'],label='MIXCR',color='#4878d0')
sns.lineplot(IMREP_5985['th'], IMREP_5985['observed_portion_frequency'],label='IMREP',color='#ee854a')
sns.lineplot(TRUST4_5985['th'], TRUST4_5985['observed_portion_frequency'],label='TRUST4',color='#6acc64')
sns.lineplot(CATT_5985['th'], CATT_5985['observed_portion_frequency'],label='CATT',color='#d65f5f')

ax.legend(['MIXCR','IMREP','TRUST4','CATT'])

plt.legend(bbox_to_anchor=(1,1), frameon=False, ncol=1, handletextpad=0.2, columnspacing=0.8, handlelength=1, prop={'size': 15})
locs, labels = plt.xticks()
ax.set_ylabel('Portion of repetoire captured by tool')
ax.set_xlabel('Clonotype frequency (%) (log)')
ax.set_xscale('log')
plt.title('TCGA-CZ-5985',y=1.1,fontsize=15)
ax.set_ylim(0,1)

# setting label sizes after creation
ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=13)
plt.xticks(rotation=45)
sns.despine()
plt.subplots_adjust(wspace=0.5)

plt.savefig("../figures/supplementary/figureS5/figureS5s.pdf",bbox_inches="tight")
plt.savefig("../figures/supplementary/figureS5/figureS5s.png",bbox_inches="tight")

plt.show()
